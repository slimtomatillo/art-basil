# %%
# Imports
import pandas as pd
import json
import requests
import re
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

def copy_json_file(source_file_path, destination_file_path):
    """
    Function to take the source path of a json file and make
    a copy of the json file to the destination_file_path.
    """
    # Step 1: Open and read the JSON file
    with open(source_file_path, 'r') as json_file:
        # Load the JSON content into a Python data structure
        data = json.load(json_file)

    # Step 2: Create or open the destination JSON file and write the data to it
    with open(destination_file_path, 'w') as destination_json_file:
        # Write the data to the destination file
        json.dump(data, destination_json_file, indent=4)  # You can use indent for pretty formatting if desired
    
    return

def save_json_file(data, file_path):
    # Step 1: Create or open the destination JSON file and write the data to it
    with open(file_path, 'w') as json_file:
        # Write the data to the destination file
        json.dump(data, json_file, indent=4)  # You can use indent for pretty formatting if desired

def standardize_text(string):
    """
    Initially designed for handling strings containing times.
    Removes periods, lowercases it, and removes spaces.
    """
    # Remove punctuation
    string = string.replace('.', '')

    # Lowercase
    string = string.lower()

    # Remove spaces
    string = string.replace(' ', '')
    
    return string

def get_de_young_events():
    """
    Uses BeautifulSoup to scrape event info from the de Young
    Museum and Legion of Honor's calendar.
    """
    print("Collecting events from the de Young & Legion of Honor...")

    # Collect event info
    events_list = []

    # Iterate through the pages
    for i in range(1, 10):

        url = "https://www.famsf.org/calendar" + f"?page={i}"
    
        # Send a GET request to fetch the webpage content
        response = requests.get(url)
        html_content = response.content
        
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # Find elements a class
        group_elements = soup.find_all(class_="mt-24 xl:mt-32")

        # If no pages left, exit loop
        if len(group_elements) == 0: # this will be 0 when we've gone through all the pages
            break
        
        for e in group_elements:
            # Instantiate list to collect tags
            tags = []
            # Extract title
            title = e.find("a").find("h3").get_text().strip()
            # Extract link
            link = e.find("a").get("href")
            # Extract date info
            date = e.find(class_="mt-12 text-secondary f-subheading-1").get_text()
            # Extract venue
            try:
                venue = e.find(class_="text-inherit pt-2 ml-8").get_text()
            except AttributeError:
                venue = "unknown"
            # Add tags
            event_type = e.find(class_="text-inherit pt-2").get_text().lower() # this is Exhibition or Event
            if event_type == "exhibition":
                tags.append("exhibition")
            if "tour" in title.lower():
                tags.append("tour")
            if "family" in title.lower():
                tags.append("family")
            if "youngster" in title.lower():
                tags.append("family")
            if "reading" in title.lower():
                tags.append("reading")
            if "concert" in title.lower():
                tags.append("audio")
            if "song bath" in title.lower():
                tags.append("audio")
            if "workshop" in title.lower():
                tags.append("workshop")
            if "free" in title.lower():
                tags.append("free")
            if "opening" in title.lower():
                tags.append("opening")
            if "member" in title.lower():
                tags.append("members only")
            if "symposium" in title.lower():
                tags.append("symposium")
            if "lecture" in title.lower():
                tags.append("talk")
            if "talk" in title.lower():
                tags.append("talk")
            if "conversation" in title.lower():
                tags.append("talk")
            if "party" in title.lower():
                tags.append("party")
            if "queer" in title.lower():
                tags.append("queer")
            if "virtual" in title.lower():
                tags.append("virtual")
            # Collect data
            events_list.append(
                {
                    "Title": title,
                    "Links": [{
                        "Link": link,
                        "Text": "Event Page",
                    }],
                    "Date": date,
                    "Venue": venue,
                    "Tags": list(set(tags)) # get unique list of tags
                }
            )

    print("Completed. Collected {:,} events.".format(len(events_list)))
    return events_list

def get_berkeley_art_center_events():
    """
    Uses BeautifulSoup to scrape event info from Berkeley Art 
    Center's calendar.
    """
    print("Collecting events from Berkeley Art Center...")

    def parse_time_to_timestamp(time_str):
        # Regular expression pattern to match time formats
        time_pattern = r'(\d{1,2}(?::\d{2})?)\s?(am|pm)?'
    
        # Match the time components
        match = re.match(time_pattern, time_str, re.IGNORECASE)
        if match:
            # Extract hours and minutes
            hours_minutes = match.group(1)
            am_pm = match.group(2)
    
            if am_pm:
                am_pm = am_pm.lower()
    
            # Convert hours to 24-hour format if needed
            if am_pm == 'pm' and ':' in hours_minutes:
                hours, minutes = hours_minutes.split(':')
                hours = str(int(hours) + 12)
                time_str = f'{hours}:{minutes}'
            elif am_pm == 'am' and ':' not in hours_minutes and len(hours_minutes) <= 2:
                hours = hours_minutes.zfill(2)
                time_str = f'{hours}:00'
            elif am_pm == 'pm' and ':' not in hours_minutes and len(hours_minutes) <= 2:
                hours = str(int(hours_minutes) + 12)
                time_str = f'{hours}:00'
    
            # Convert the time string to a datetime timestamp
            try:
                timestamp = datetime.strptime(time_str, '%H:%M').time()
                return timestamp
            except ValueError:
                return None

        return None
    
    # Collect event info
    events_list = []
    
    # URL of the website to scrape
    url = "https://www.berkeleyartcenter.org/calendar"
    
    # Send a GET request to fetch the webpage content
    response = requests.get(url)
    html_content = response.content
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # We'll use this later to identify dates
    days_of_week = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

    # Get elements
    elements = soup.find_all(class_="col sqs-col-6 span-6")

    # Iterate through elements
    for e in elements:
        # If looking at past events, stop the loop
        if "past events" in e.find_previous("h1").text.lower():
            break
        # Otherwise, we're looking at current events --> collect events
        else:
            h3s = e.find_all("h3")
            # If there are any h3 elements
            if len(h3s) > 0:
                # Collect date(s)
                dates = []
                # Identify title
                title = h3s[0].get_text().strip()
                # Collect tags
                tags = []
                # Collect links
                links = []
                # Iterate through h3 elements
                for h in h3s:
                    if any(x in h.get_text().lower() for x in days_of_week):
                        dates.append(h.get_text().strip())
                    # Tag events
                    if "opening" in h.get_text().lower():
                        tags.append("opening")
                    if "conversation" in h.get_text().lower():
                        tags.append("talk")
                    if "talk" in h.get_text().lower():
                        tags.append("talk")
                    if "dialogue" in h.get_text().lower():
                        tags.append("talk")
                    if "performance" in h.get_text().lower():
                        tags.append("performance")
                    if "workshop" in h.get_text().lower():
                        tags.append("workshop")
                    if "party" in h.get_text().lower():
                        tags.append("party")
                    if "queer" in h.get_text().lower():
                        tags.append("queer")
                    if "virtual" in h.get_text().lower():
                        tags.append("virtual")
                    if "zoom" in h.get_text().lower():
                        tags.append("virtual")
                # Combined dates
                date = " | ".join(dates)
                date_text = date # copy date text to use for other purpose
                date = date.replace(" on zoom.", "")
                # Identify location
                try:
                    "berkeley art center" in h3s[2].get_text().lower()
                    venue = h3s[2].get_text()
                except IndexError:
                    venue = "Berkeley Art Center"
                else:
                    venue = "Berkeley Art Center"
                if "on zoom" in date_text.lower():
                    venue = "Virtual"
                # Get link
                link_elements = e.find_all("a")
                if len(link_elements) > 0:
                    for l in link_elements:
                        link_url = l.get("href")
                        if "eventbrite" in link_url.lower():
                            links.append({
                                "Link": link_url,
                                "Text": "Eventbrite"
                            })
                        elif ("berkeleyartcenter" in link_url.lower() and link_url.lower() != "https://www.berkeleyartcenter.org/upcoming-exhibitions"):
                            links.append({
                                "Link": link_url,
                                "Text": "Event Page"
                            })
                        else:
                            links.append({
                                "Link": link_url,
                                "Text": "unknown"
                            })
                # // Extract time //
                # Get the last item after the last space and standardize it
                time = standardize_text(date.split(' ')[-1])
                # If there is a hyphen, that indicates there is a start and end time
                if '–' in date:
                    # Get the start date from the left side of the hyphen
                    start_time = time.split('–')[0]
                    # Get the start date from the right side of the hyphen
                    try:
                        end_time = time.split('–')[1]
                    except IndexError:
                        end_time = None
                    # If the end time is AM, then the start time must be AM
                    if 'am' in end_time:
                        start_time += 'am'
                    # If the end time is PM
                    else:
                        # If the hour of the start time is before the hour of the end time, it must be PM
                        if int(start_time) < int(end_time.replace('am', '').replace('pm', '')):
                            start_time += 'pm'
                        # If the hour is after, it must be AM
                        else:
                            start_time += 'am'
                # If there is no end time / just a start time
                else:
                    start_time = time
                    end_time = None
                # // Identify sorting index
                # If we have the start time, use that to sort
                if start_time:
                    time_sort = parse_time_to_timestamp(start_time)
                    # Convert the datetime object to a string in a specific format
                    time_sort = time_sort.strftime("%H:%M:%S")
                # Otherwise use the end time if we have it
                elif end_time:
                    time_sort = parse_time_to_timestamp(end_time)
                    # Convert the datetime object to a string in a specific format
                    time_sort = time_sort.strftime("%H:%M:%S")
                # Collect event data
                events_list.append(
                    {
                        "Title": title,
                        "Links": links,
                        "Date": date,
                        "StartTime": start_time,
                        "EndTime": end_time,
                        "TimeSort": time_sort,
                        "Venue": venue,
                        "Tags": list(set(tags)) # get unique list of tags
                    }
                )
    print("Completed. Collected {:,} events.".format(len(events_list)))
    return events_list

def is_event_recurring(event_str):
    """
    Function that takes in a string containing date and time information
    about an event and identifies whether it is a recurring event or not.
    """
    # Check if the string contains "through" (case insensitive)
    if re.search(r'through', event_str, re.IGNORECASE):
        return True

    # Check if the string contains a "–" or "," between two days of the week or abbreviations
    if re.search(r'(\w{3} – \w{3}|\w{3}, \w{3})', event_str):
        return True

    # Check if the string contains a "+" and has more than one day of the week or abbreviations
    if re.search(r'\+\s*(\w{3}|\w{3},)+', event_str):
        return True

    return False

def main():
    """
    Function that:
        1. Saves a copy of existing data
        2. Scrapes data from the de Young Museum & Legion of Honor
        3. Scrapes data from the Berkeley Art Center
        4. Saves data as json
    """

    # Save a copy of existing json data
    try:
        copy_json_file('website/data.json', 'website/data_copy.json')
    except FileNotFoundError:
        pass

    # Instantiate list to collect data
    data = []

    # Scrape data from the de Young Museum & Legion of Honor
    de_young_data = get_de_young_events()
    data += de_young_data

    # Scrape data from the Berkeley Art Center
    berkeley_art_center_data = get_berkeley_art_center_events()
    data += berkeley_art_center_data

    # # Save data as json
    # save_json_file(data, 'website/data.json')
    # print("."*15)
    # print("Saved {:,} events.".format(len(data)))

    return data

# if __name__ == "__main__":
#     main()

# %%
data = main()
# Out:
# Collecting events from the de Young & Legion of Honor...
# Completed. Collected 51 events.
# Collecting events from Berkeley Art Center...
# Completed. Collected 2 events.

# %%
data
# Out:
# [{'Title': 'Nampeyo and the Sikyátki Revival',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/nampeyo-and-sikyatki-revival',
#     'Text': 'Event Page'}],
#   'Date': 'Through Sep 15, 2024',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Lhola Amira: Facing the Future',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/lhola-amira',
#     'Text': 'Event Page'}],
#   'Date': 'Through Dec 3, 2023',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Organ Concert',
#   'Links': [{'Link': 'https://www.famsf.org/events/organ-concert',
#     'Text': 'Event Page'}],
#   'Date': 'Sat \\ 4 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['audio']},
#  {'Title': 'Free Saturdays at the Legion of Honor',
#   'Links': [{'Link': 'https://www.famsf.org/events/free-saturdays-legion-of-honor',
#     'Text': 'Event Page'}],
#   'Date': 'Sat \\ 9:30 am – 5:15 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['free']},
#  {'Title': 'Highlights Tour',
#   'Links': [{'Link': 'https://www.famsf.org/events/highlights-tour',
#     'Text': 'Event Page'}],
#   'Date': 'Tues – Fri, Sun \\ Noon – 1 pm, 2 – 3 pm',
#   'Venue': 'de Young',
#   'Tags': ['tour']},
#  {'Title': 'Kehinde Wiley: An Archaeology of Silence',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/kehinde-wiley-an-archaeology-of-silence',
#     'Text': 'Event Page'}],
#   'Date': 'Through Oct 15, 2023',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Printworks: Recent Gifts from the Archives',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/printworks',
#     'Text': 'Event Page'}],
#   'Date': 'Through Oct 1, 2023',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Free Saturdays at the de Young',
#   'Links': [{'Link': 'https://www.famsf.org/events/free-saturdays-de-young',
#     'Text': 'Event Page'}],
#   'Date': 'Sat \\ 9:30 am – 5:15 pm',
#   'Venue': 'de Young',
#   'Tags': ['free']},
#  {'Title': 'The Tudors: Art and Majesty in Renaissance England',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/tudors',
#     'Text': 'Event Page'}],
#   'Date': 'Through Sep 24, 2023',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'Docent Tour: The Tudors',
#   'Links': [{'Link': 'https://www.famsf.org/events/docent-tour-the-tudors',
#     'Text': 'Event Page'}],
#   'Date': 'Tues – Sun \\ 11:30 am + 1:30 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['tour']},
#  {'Title': 'Compelling Conversations',
#   'Links': [{'Link': 'https://www.famsf.org/events/compelling-conversations',
#     'Text': 'Event Page'}],
#   'Date': 'Sat \\ noon – 12:40 pm, 3 – 3:40 pm',
#   'Venue': 'de Young',
#   'Tags': ['talk']},
#  {'Title': 'Bouke de Vries: Memories in Porcelain',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/bouke-de-vries-porcelain',
#     'Text': 'Event Page'}],
#   'Date': 'Through Mar 24, 2024',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'Crafting Radicality: Bay Area Artists from the Svane Gift',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/crafting-radicality-bay-area-artists',
#     'Text': 'Event Page'}],
#   'Date': 'Through Dec 31, 2023',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Docent Tour: Bouke de Vries',
#   'Links': [{'Link': 'https://www.famsf.org/events/docent-tour-bouke-de-vries',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sun, Tues \\ 11:30 am – 1:30 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['tour']},
#  {'Title': 'Family Tour',
#   'Links': [{'Link': 'https://www.famsf.org/events/family-tour-0',
#     'Text': 'Event Page'}],
#   'Date': 'Select Saturdays \\ 10:30 am',
#   'Venue': 'de Young',
#   'Tags': ['tour', 'family']},
#  {'Title': 'Drawing the Line: Michelangelo to Asawa',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/drawing-the-line',
#     'Text': 'Event Page'}],
#   'Date': 'Through Feb 25, 2024',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'Family Art Making',
#   'Links': [{'Link': 'https://www.famsf.org/events/family-art-making-0',
#     'Text': 'Event Page'}],
#   'Date': 'Select Saturdays \\ 11 am – 3 pm',
#   'Venue': 'de Young',
#   'Tags': ['family']},
#  {'Title': 'Benoit Éditeur',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/benoit-editeur',
#     'Text': 'Event Page'}],
#   'Date': 'Through Mar 10, 2024',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'Sketching in the Galleries',
#   'Links': [{'Link': 'https://www.famsf.org/events/sketching-in-the-galleries',
#     'Text': 'Event Page'}],
#   'Date': 'Select Saturdays \\ 11 am – 3 pm',
#   'Venue': 'de Young',
#   'Tags': []},
#  {'Title': 'Docent Tour: Drawing the Line',
#   'Links': [{'Link': 'https://www.famsf.org/events/docent-tour-drawing-the-line',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sun, Free Tues \\ 11:30 am + 1 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['tour']},
#  {'Title': 'Voices of Contemporary Artists Lecture: Hangama Amiri',
#   'Links': [{'Link': 'https://www.famsf.org/events/contemporary-artists-lecture-hangama-amiri',
#     'Text': 'Event Page'}],
#   'Date': 'Thu, Sep 7 \\ 1 – 2:15 pm',
#   'Venue': 'de Young',
#   'Tags': ['talk']},
#  {'Title': 'Babylonian Astrology and the History of Science',
#   'Links': [{'Link': 'https://www.famsf.org/events/babylonian-astrology-history-science',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 9 \\ 2 – 3:30 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': []},
#  {'Title': 'The Tudors Virtual Access Day',
#   'Links': [{'Link': 'https://www.famsf.org/events/the-tudors-virtual-access-day',
#     'Text': 'Event Page'}],
#   'Date': 'Mon, Sep 11',
#   'Venue': 'Virtual',
#   'Tags': ['virtual']},
#  {'Title': 'Our Shared Struggle: The International Imperative for Repair',
#   'Links': [{'Link': 'https://www.famsf.org/events/our-shared-struggle-event',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 16 \\ 1 pm',
#   'Venue': 'de Young',
#   'Tags': []},
#  {'Title': 'The Quiet Hours Workshop with Angela Hennessy + Marvin K. White',
#   'Links': [{'Link': 'https://www.famsf.org/events/quiet-hours-workshop-3',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 16 \\ 3 – 5 pm',
#   'Venue': 'de Young',
#   'Tags': ['workshop']},
#  {'Title': 'Rise of the Ruff: Tudor + Elizabethan Costume Demonstration',
#   'Links': [{'Link': 'https://www.famsf.org/events/tudor-elizabethan-costume-demonstration',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 23 \\ 10 am – noon + 1 – 3 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': []},
#  {'Title': 'Tudor Calligraphy with Benjamin Yates',
#   'Links': [{'Link': 'https://www.famsf.org/events/tudor-calligraphy-benjamin-yates-3',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 23 \\ 10 – 11 am + 1 – 2 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': []},
#  {'Title': 'The de Young Open Member Preview Days',
#   'Links': [{'Link': 'https://www.famsf.org/events/de-young-open-member-preview-days',
#     'Text': 'Event Page'}],
#   'Date': 'Thu, Sep 28 + Fri, Sep 29 \\ 9:30 am – 5:15 pm',
#   'Venue': 'de Young',
#   'Tags': ['members only']},
#  {'Title': 'The de Young Open 2023',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/de-young-open-2023',
#     'Text': 'Event Page'}],
#   'Date': 'Sep 30, 2023 – Jan 7, 2024',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Opening Day Celebration for The de Young Open',
#   'Links': [{'Link': 'https://www.famsf.org/events/opening-day-celebration-de-young-open',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 30 \\ 11 am – 4 pm',
#   'Venue': 'de Young',
#   'Tags': ['opening']},
#  {'Title': 'Cork + Craft with Shogun Shido a.k.a DJ Jambalaya',
#   'Links': [{'Link': 'https://www.famsf.org/events/cork-craft-shogun-shido',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Sep 30 \\ Noon – 4 pm',
#   'Venue': 'de Young',
#   'Tags': []},
#  {'Title': 'Studio Visit with Rashaad Newsome',
#   'Links': [{'Link': 'https://www.famsf.org/events/studio-visit-rashaad-newsome',
#     'Text': 'Event Page'}],
#   'Date': 'Thu, Oct 5 \\ 11 am – 1 pm',
#   'Venue': 'unknown',
#   'Tags': []},
#  {'Title': 'Contemporary Indigenous Voices of California’s South Coast Range',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/contemporary-indigenous-voices',
#     'Text': 'Event Page'}],
#   'Date': 'Oct 7, 2023 – Jan 7, 2024',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Gladiators at Pompeii: Roman Spectacle in a Small Town',
#   'Links': [{'Link': 'https://www.famsf.org/events/gladiators-pompeii-roman-spectacle',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Oct 7 \\ 2 – 3:30 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': []},
#  {'Title': 'Opening Day: Contemporary Indigenous Voices of California’s South Coast Range',
#   'Links': [{'Link': 'https://www.famsf.org/events/opening-day-contemporary-indigenous-voices',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Oct 7 \\ 11 am – 2:15 pm',
#   'Venue': 'de Young',
#   'Tags': ['opening']},
#  {'Title': 'The San Francisco Fall Show',
#   'Links': [{'Link': 'https://www.famsf.org/events/san-francisco-fall-show',
#     'Text': 'Event Page'}],
#   'Date': 'Wed, Oct 11 – Sun, Oct 15',
#   'Venue': 'unknown',
#   'Tags': []},
#  {'Title': 'Kehinde Wiley Grand Finale Concert',
#   'Links': [{'Link': 'https://www.famsf.org/events/kehinde-wiley-grand-finale-concert',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Oct 14 \\ 9 am – 6 pm',
#   'Venue': 'unknown',
#   'Tags': ['audio']},
#  {'Title': 'Annual Donors’ Luncheon: Director’s Preview',
#   'Links': [{'Link': 'https://www.famsf.org/events/annual-donors-luncheon-director-preview',
#     'Text': 'Event Page'}],
#   'Date': 'Mon, Oct 16 \\ 11 am',
#   'Venue': 'de Young',
#   'Tags': []},
#  {'Title': 'The de Young Open Access Day',
#   'Links': [{'Link': 'https://www.famsf.org/events/de-young-open-access-day',
#     'Text': 'Event Page'}],
#   'Date': 'Mon, Oct 23 \\ 9:30 am – 2:30 pm',
#   'Venue': 'de Young',
#   'Tags': []},
#  {'Title': 'Botticelli Drawings Member Preview Day',
#   'Links': [{'Link': 'https://www.famsf.org/events/botticelli-drawings-member-preview-day',
#     'Text': 'Event Page'}],
#   'Date': 'Fri, Nov 17 \\ 1 – 5:15 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['members only']},
#  {'Title': 'Botticelli Drawings Member Preview Day',
#   'Links': [{'Link': 'https://www.famsf.org/events/botticelli-drawings-member-preview-day-2',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Nov 18 \\ 9:30 am – 5:15 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['members only']},
#  {'Title': 'A Symposium on Botticelli',
#   'Links': [{'Link': 'https://www.famsf.org/events/symposium-on-botticelli',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Nov 18 \\ 1 – 5 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['symposium']},
#  {'Title': 'Botticelli Drawings',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/botticelli-drawings',
#     'Text': 'Event Page'}],
#   'Date': 'Nov 19, 2023 – Feb 11, 2024',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'Rehearsed Reading of Ion by Euripides',
#   'Links': [{'Link': 'https://www.famsf.org/events/rehearsed-reading-ion-euripides',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, Dec 2 \\ 2 – 3:30 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': ['reading']},
#  {'Title': 'An Elegant Evening in the Court of Honor',
#   'Links': [{'Link': 'https://www.famsf.org/events/elegant-evening',
#     'Text': 'Event Page'}],
#   'Date': 'Tue, Dec 12 \\ 7 – 11:30 pm',
#   'Venue': 'Legion of Honor',
#   'Tags': []},
#  {'Title': 'Fashioning San Francisco: A Century of Style',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/fashioning-san-francisco',
#     'Text': 'Event Page'}],
#   'Date': 'Jan 20 – Aug 11, 2024',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Lee Mingwei: Rituals of Care',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/lee-mingwei',
#     'Text': 'Event Page'}],
#   'Date': 'Feb 17 – Jul 7, 2024',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Irving Penn',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/irving-penn',
#     'Text': 'Event Page'}],
#   'Date': 'Mar 16 – Jul 21, 2024',
#   'Venue': 'de Young',
#   'Tags': ['exhibition']},
#  {'Title': 'Zuan-cho: Kimono Design in Modern Japan (1868–1912)',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/zuan-cho-kimono-design',
#     'Text': 'Event Page'}],
#   'Date': 'Mar 30 – Aug 25, 2024',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'Japanese Prints in Transition: From the Floating World to the Modern World',
#   'Links': [{'Link': 'https://www.famsf.org/exhibitions/japanese-prints',
#     'Text': 'Event Page'}],
#   'Date': 'Apr 6 – Aug 18, 2024',
#   'Venue': 'Legion of Honor',
#   'Tags': ['exhibition']},
#  {'Title': 'de Youngsters Day Out 2024',
#   'Links': [{'Link': 'https://www.famsf.org/events/de-youngsters-day-out-2024',
#     'Text': 'Event Page'}],
#   'Date': 'Sat, May 4',
#   'Venue': 'de Young',
#   'Tags': ['family']},
#  {'Title': 'OÑI OCAN: A RITUAL PERFORMANCE BY COURTNEY DESIREE MORRIS',
#   'Links': [{'Link': 'https://www.eventbrite.com/e/oni-ocan-a-ritual-performance-by-courtney-desiree-morris-tickets-697681232347?aff=oddtdtcreator',
#     'Text': 'Eventbrite'}],
#   'Date': 'Friday, september 8, 6–8PM',
#   'StartTime': '6pm',
#   'EndTime': '8pm',
#   'TimeSort': '18:00:00',
#   'Venue': 'Berkeley Art Center',
#   'Tags': ['performance']},
#  {'Title': 'Community Dinner',
#   'Links': [{'Link': 'https://www.eventbrite.com/e/705586196307?aff=oddtdtcreator',
#     'Text': 'Eventbrite'}],
#   'Date': 'Tuesday, August 29 from 7–8PM',
#   'StartTime': '7pm',
#   'EndTime': '8pm',
#   'TimeSort': '19:00:00',
#   'Venue': 'Virtual',
#   'Tags': ['virtual']}]

# %%
time_str = 'Sat \\ 9:30 am – 5:15 pm'
time_str = 'Tues – Sun \\ 11:30 am + 1:30 pm'

# %%
# // Extract time //
# If there is \\ in it, there's a time
if '\\' in time_str:
    # Split by \\ and choose [-1], then by , and choose [0], and remove spaces
    time = time_str.split('\\')[-1].split(',')[0].replace(' ', '')
    # If a hyphen ("–") is in it, there is a start and end time, split by dash
    if '–' in time:
        start_time = time.split('–')[0]
        end_time = time.split('–')[1]
    # Elif a + is in it, there are two start times, split by +
    elif '+' in time:
        start_time = time.split('+')[0]
    # Otherwise
    else:
        start_time = None
        end_time = None

# // Identify sorting index //
# If we have the start time, use that to sort
if start_time:
    time_sort = parse_time_to_timestamp(start_time)
    # Convert the datetime object to a string in a specific format
    # time_sort = time_sort.strftime("%H:%M:%S")
# Otherwise use the end time if we have it
elif end_time:
    time_sort = parse_time_to_timestamp(end_time)
    # Convert the datetime object to a string in a specific format
    # time_sort = time_sort.strftime("%H:%M:%S")

print(time_str)
print(start_time)
print(end_time)
print(time_sort)
# Out:
# Tues – Sun \ 11:30 am + 1:30 pm
# 11:30am
# None
# None

# %%
parse_time_to_timestamp('11:30 am')

# %%
# If am or pm are in it, theres a time

    # If a hyphen ("–") is in it, there is a start and end time, split by dash

    # Elif a + is in it, there are two start times, split by +

# %%
# Maybe add "DateTimeDisplayText" for the date/time text that is displayed
