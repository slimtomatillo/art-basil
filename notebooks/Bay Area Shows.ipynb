# %%
# Imports
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ## Schools

# %%
# List out bay area schools (colleges and universities)
bay_area_schools = [
    {
        "Name": "UC Berkeley",
        "Links": [
            {
                "Link": "https://art.berkeley.edu/department-calendar",
                "Description": "Departmental Calendar"
            },
            {
                "Link": "https://events.berkeley.edu/ah/",
                "Description": "Arts & Humanities Calendar"
            }
        ]
    },
    # "Stanford",
    {
        "Name": "California College of the Arts (CCA)",
        "Links": [
            {
                "Link": "https://portal.cca.edu/events-calendar/?daterange_predefined=ALL&p=1",
                "Description": "Events Calendar"
            }
        ]
    },
    # "San Francisco State University (SFSU)",
    # "Univserity of San Francisco (USF)",
]

# %%
bay_area_schools
# Out:
# [{'Name': 'UC Berkeley',
#   'Links': [{'Link': 'https://art.berkeley.edu/department-calendar',
#     'Description': 'Departmental Calendar'}]},
#  {'Name': 'California College of the Arts (CCA)',
#   'Links': [{'Link': 'https://portal.cca.edu/events-calendar/?daterange_predefined=ALL&p=1',
#     'Description': 'Events Calendar'}]}]

# %%
# List school names
[school["Name"] for school in bay_area_schools]
# Out:
# ['UC Berkeley', 'California College of the Arts (CCA)']

# %%
# List all links
[[link["Link"] for link in school["Links"]][0] for school in bay_area_schools]
# Out:
# ['https://art.berkeley.edu/department-calendar',
#  'https://portal.cca.edu/events-calendar/?daterange_predefined=ALL&p=1']

# %%
# URL of the website to scrape
url = 'https://art.berkeley.edu/department-calendar'

# Send a GET request to fetch the webpage content
response = requests.get(url)
html_content = response.content

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Get p elements --> each p is a time period
p_elements = soup.find_all("p")

# Store event data
event_list = []

for p in p_elements:
    # Skip first p element if it's the intro text
    if "For more information on each event, visit the corresponding page on this website" not in p.get_text():
        events_raw = p.get_text()
        # print(events_raw)

        # How many events in this period?
        # Use this regex pattern to match occurrences of a left and right parenthesis with 3 or 4 of any character in bewteen --> (XXX) or (XXXX)
        pattern = r"\(.{3,4}\)"
        results = re.findall(pattern, events_raw)
        # Remove occurrences of "(Zoom)"
        results = [r for r in results if r != "(Zoom)"]
        num_events = len(results)
        # We don't care about the text that doesn't contain any events
        if num_events > 0:
            events = events_raw.split(") ")
            events = [e for e in events if e != "" and e not in ["(Mon", "(Tue", "(Tues", "(Wed", "(Th", "(Thu", "(Thurs", "(Fri", "(Sat", "(Sun"]]
            for e in events:
                if len(e) > 20: # This takes care of small bits of text that got caught
                    event_dict = {}
                    print(e)
                    date = e.split(": ")[0]
                    name = e.split(": ", 1)[1].split(",")[0]
                    try:
                        time = e.split(": ", 1)[1].split(",")[1].strip()
                    except IndexError:
                        time = "unknown"
                    try:
                        location = e.split(": ", 1)[1].split(",")[2].strip().replace("(Mon", "").replace("(Tu", "")\
                        .replace("(Tues", "").replace("(Wed", "").replace("(Th", "").replace("(Thu", "").replace("(Thurs", "")\
                        .replace("(Fri", "").replace("(Sat", "").replace("(Sun", "").split(".")[0]
                    except IndexError:
                        location = 'unknown'
                    print("Date:", date)
                    print("Name:", name)
                    print("Time:", time)
                    print("Location:", location)
                    print()
                    event_dict["Date"] = date
                    event_dict["Name"] = name
                    event_dict["Time"] = time
                    event_dict["Location"] = location
                    event_list.append(event_dict)
# Out:
# August 30: Reception: “Black chicagoland is…”,  5-7 pm, Worth Ryder Art Gallery (AAPB 116)
# Date: August 30
# Name: Reception: “Black chicagoland is…”
# Time: 5-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# May. 3: Senior Exhibit “Textured Overflow.”, 5-7 pm, Worth Ryder Art Gallery (AAPB 116)(Wed
# Date: May. 3
# Name: Senior Exhibit “Textured Overflow.”
# Time: 5-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# April. 12: Blood Pressure and Here Lies, 4-7 pm, Worth Ryder Art Gallery (AAPB 116)(Wed
# Date: April. 12
# Name: Blood Pressure and Here Lies
# Time: 4-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Jan. 18: Reception: Cacophonies of Resistance, 4-7 pm, Worth Ryder Art Gallery (AAPB 116). Featuring a performance by Valencia James.(Wed
# Date: Jan. 18
# Name: Reception: Cacophonies of Resistance
# Time: 4-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Feb. 8: Closing Reception and Catalogue Preview: Cacophonies of Resistance, 4-7 pm, Worth Ryder Art Gallery (AAPB 116)(Wed
# Date: Feb. 8
# Name: Closing Reception and Catalogue Preview: Cacophonies of Resistance
# Time: 4-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Feb. 22: Reception: Emergenc(y): Afghan Lives Beyond the Forever War, 5-7 pm, Worth Ryder Art Gallery (AAPB 116).                                                                   (Wed
# Date: Feb. 22
# Name: Reception: Emergenc(y): Afghan Lives Beyond the Forever War
# Time: 5-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Feb 23 - 28: Remembering a Future#2, Performance Lecture by Amanullah Mojadidi(Sat
# Date: Feb 23 - 28
# Name: Remembering a Future#2
# Time: Performance Lecture by Amanullah Mojadidi(Sat
# Location: unknown
#
# Mar.4: Writing Afghan Lives Beyond the Forever War A Book Reading and Dance Performance, 1-3pm, Worth Ryder Art Gallery (AAPB 116). (Wed
# Date: Mar.4
# Name: Writing Afghan Lives Beyond the Forever War A Book Reading and Dance Performance
# Time: 1-3pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Apr 12: Reception: Honors Exhibit, 5-7 pm, Worth Ryder Art Gallery (AAPB 116).  (Wed
# Date: Apr 12
# Name: Reception: Honors Exhibit
# Time: 5-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# May 3: Reception: Senior Exhibit, 5-7 pm, Worth Ryder Art Gallery (AAPB 116).
# Date: May 3
# Name: Reception: Senior Exhibit
# Time: 5-7 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Aug. 24: Instruction begins (in person)(Tues
# Date: Aug. 24
# Name: Instruction begins (in person)(Tues
# Time: unknown
# Location: unknown
#
# Aug. 30: New lecturer orientation, 12-1pm (online)(Wed
# Date: Aug. 30
# Name: New lecturer orientation
# Time: 12-1pm (online)(Wed
# Location: unknown
#
# Aug.31: Reception: Art for the Asking, 4-6pm, Worth Ryder Art Gallery (AAPB 116)(Thurs
# Date: Aug.31
# Name: Reception: Art for the Asking
# Time: 4-6pm
# Location: Worth Ryder Art Gallery (AAPB 116)urs
#
# Sept. 8: “New Bulldozer Alarm!” exhibition opening, Platform Artspace, 4-6pm(Fri
# Date: Sept. 8
# Name: “New Bulldozer Alarm!” exhibition opening
# Time: Platform Artspace
# Location: 4-6pm
#
# Sept. 16: Departmental meeting (online)(Sun
# Date: Sept. 16
# Name: Departmental meeting (online)(Sun
# Time: unknown
# Location: unknown
#
# Sept. 18: Art Practice major applications due(Sun
# Date: Sept. 18
# Name: Art Practice major applications due(Sun
# Time: unknown
# Location: unknown
#
# Oct. 2: Fall 2022 Materials Quik-Grants due(Wed
# Date: Oct. 2
# Name: Fall 2022 Materials Quik-Grants due(Wed
# Time: unknown
# Location: unknown
#
# Oct.19:  Honors Exhibition Opening Reception, 4-6 pm, Worth Ryder Art Gallery (AAPB 116)(Wed
# Date: Oct.19
# Name:  Honors Exhibition Opening Reception
# Time: 4-6 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Oct.19: Badri Valian's “Virgins in Heaven,” exhibition opening, 4-6pm, Worth Ryder Art Gallery (AAPB 116)(Wed
# Date: Oct.19
# Name: Badri Valian's “Virgins in Heaven
# Time: ” exhibition opening
# Location: 4-6pm
#
# Nov.16: Senior Exhibit Opening Reception, 4-6 pm, Worth Ryder Art Gallery (AAPB 116)
# Date: Nov.16
# Name: Senior Exhibit Opening Reception
# Time: 4-6 pm
# Location: Worth Ryder Art Gallery (AAPB 116)
#
# Jan. 18: Instruction begins (online)(Fri
# Date: Jan. 18
# Name: Instruction begins (online)(Fri
# Time: unknown
# Location: unknown
#
# Jan. 21: Departmental meeting(Tue
# Date: Jan. 21
# Name: Departmental meeting(Tue
# Time: unknown
# Location: unknown
#
# Jan. 25: Artist Talk: Jeffrey Gibson, Wiesenfeld Visiting Artist Lecture Series / Arts Research Center, 4-5:30pm, online(Wed
# Date: Jan. 25
# Name: Artist Talk: Jeffrey Gibson
# Time: Wiesenfeld Visiting Artist Lecture Series / Arts Research Center
# Location: 4-5:30pm
#
# Jan. 26: First Year MFA exhibition “Optimal Conditions” opens in Worth Ryder Art Gallery(Fri), Jan. 28: “Optimal Conditions” performance by Gericault De La Rose: 7-8:30pm, accessible by live stream(Mon
# Date: Jan. 26
# Name: First Year MFA exhibition “Optimal Conditions” opens in Worth Ryder Art Gallery(Fri)
# Time: Jan. 28: “Optimal Conditions” performance by Gericault De La Rose: 7-8:30pm
# Location: accessible by live stream
#
# Jan. 31: Instruction begins in-person (projected date, subject to university change)
# Date: Jan. 31
# Name: Instruction begins in-person (projected date
# Time: subject to university change)
# Location: unknown
#
# Feb. 8: Artist Talk: Hajra Waheed, Crisis and Creativity: Artists Speak / Wiesenfeld Visiting Artist Lecture Series / South Asia Studies, 9am, online(Wed
# Date: Feb. 8
# Name: Artist Talk: Hajra Waheed
# Time: Crisis and Creativity: Artists Speak / Wiesenfeld Visiting Artist Lecture Series / South Asia Studies
# Location: 9am
#
# Feb. 9: Deadline to add/drop classes(Wed
# Date: Feb. 9
# Name: Deadline to add/drop classes(Wed
# Time: unknown
# Location: unknown
#
# Feb. 9: Art Practice major application info session with Raty Syka and Stephanie Syjuco, 12-1pm, Zoom.(Fri
# Date: Feb. 9
# Name: Art Practice major application info session with Raty Syka and Stephanie Syjuco
# Time: 12-1pm
# Location: Zoom
#
# Feb. 18: Art Practice major applications due(Fri
# Date: Feb. 18
# Name: Art Practice major applications due(Fri
# Time: unknown
# Location: unknown
#
# Feb. 18: “Optimal Conditions” performance by Irma Yuliana Barbosa, 5-6pm, AAP 120. Please register here for a seat. (Fri
# Date: Feb. 18
# Name: “Optimal Conditions” performance by Irma Yuliana Barbosa
# Time: 5-6pm
# Location: AAP 120
#
# Feb. 18: Departmental meeting(Mon
# Date: Feb. 18
# Name: Departmental meeting(Mon
# Time: unknown
# Location: unknown
#
# Feb. 21: Holiday (Tues
# Date: Feb. 21
# Name: Holiday (Tues
# Time: unknown
# Location: unknown
#
# Feb. 22—Tuesday, March 1: Student exhibition TBA opens in Worth Ryder Art Gallery(Mon
# Date: Feb. 22—Tuesday, March 1
# Name: Student exhibition TBA opens in Worth Ryder Art Gallery(Mon
# Time: unknown
# Location: unknown
#
# Feb. 28: Artist Talk: The New Red Order, Berkeley Arts + Design, 6:30-8pm
# Date: Feb. 28
# Name: Artist Talk: The New Red Order
# Time: Berkeley Arts + Design
# Location: 6:30-8pm
#
# Mar. 2: Exhibitions PROOF: 28 years of printmaking at UC Berkeley  and (Im)print open in Worth Ryder Art Gallery, 4-6 pm.(Sun
# Date: Mar. 2
# Name: Exhibitions PROOF: 28 years of printmaking at UC Berkeley  and (Im)print open in Worth Ryder Art Gallery
# Time: 4-6 pm.(Sun
# Location: unknown
#
# March 6: Materials Quik-Grant applications due(Tue
# Date: March 6
# Name: Materials Quik-Grant applications due(Tue
# Time: unknown
# Location: unknown
#
# March 15: Artist Talk: Dario Robleto, Wiesenfeld Visiting Artist Lecture Series / Arts Research Center, 4-5:30pm, online(Fri
# Date: March 15
# Name: Artist Talk: Dario Robleto
# Time: Wiesenfeld Visiting Artist Lecture Series / Arts Research Center
# Location: 4-5:30pm
#
# March 18: Departmental meeting(Mon
# Date: March 18
# Name: Departmental meeting(Mon
# Time: unknown
# Location: unknown
#
# March 21—Friday, March 25: Spring Break(Sat
# Date: March 21—Friday, March 25
# Name: Spring Break(Sat
# Time: unknown
# Location: unknown
#
# March 26: MFA Open Studios, Richmond Field Station, 10am-2pm(Wed
# Date: March 26
# Name: MFA Open Studios
# Time: Richmond Field Station
# Location: 10am-2pm
#
# March 30: Visiting Artist: Aman Mojadidi, Wiesenfeld Visiting Artist Lecture Series / Center for Middle Eastern Studies, time 12:00 PM, online
# Date: March 30
# Name: Visiting Artist: Aman Mojadidi
# Time: Wiesenfeld Visiting Artist Lecture Series / Center for Middle Eastern Studies
# Location: time 12:00 PM
#
# April 1: Artist Talk: Wendy Red Star, Wiesenfeld Visiting Artist Lecture Series / Arts Research Center, 4-5:30pm, online(Fri
# Date: April 1
# Name: Artist Talk: Wendy Red Star
# Time: Wiesenfeld Visiting Artist Lecture Series / Arts Research Center
# Location: 4-5:30pm
#
# April 1: Deadline to change grading options(Wed
# Date: April 1
# Name: Deadline to change grading options(Wed
# Time: unknown
# Location: unknown
#
# April 6: Exhibition Opening: Embodied Entropy, 4-6 pm, Worth Ryder Art Gallery (AAP 116
# Date: April 6
# Name: Exhibition Opening: Embodied Entropy
# Time: 4-6 pm
# Location: Worth Ryder Art Gallery (AAP 116
#
# April 12: Talk: Arundhati Roy, Center for Race and Gender, 4-5:30pm(Thurs
# Date: April 12
# Name: Talk: Arundhati Roy
# Time: Center for Race and Gender
# Location: 4-5:30pmurs
#
# April 14: Artist Talk: Seitu Jones: George's Blues: An Investigation of George Washington Carver’s Legacy as an Artist and Cook, Art, Technology and Culture Colloquium (Fri
# Date: April 14
# Name: Artist Talk: Seitu Jones: George's Blues: An Investigation of George Washington Carver’s Legacy as an Artist and Cook
# Time: Art
# Location: Technology and Culture Colloquium
#
# April 15: Departmental meeting(Mon
# Date: April 15
# Name: Departmental meeting(Mon
# Time: unknown
# Location: unknown
#
# April 18: Artist Talk: Iman Mersal, Wiesenfeld Visiting Artist Lecture Series / Center for Middle Eastern Studies, time 5:00 PM, in-person
# Date: April 18
# Name: Artist Talk: Iman Mersal
# Time: Wiesenfeld Visiting Artist Lecture Series / Center for Middle Eastern Studies
# Location: time 5:00 PM
#
# May 2—Friday, May 6: RRR Week(Wed
# Date: May 2—Friday, May 6
# Name: RRR Week(Wed
# Time: unknown
# Location: unknown
#
# May 4: Exhibition Opening: Extro-Introspection: Spring 2022 Senior Thesis Exhibition, 4-6 pm, Worth Ryder Art Gallery (AAP 116)(Mon
# Date: May 4
# Name: Exhibition Opening: Extro-Introspection: Spring 2022 Senior Thesis Exhibition
# Time: 4-6 pm
# Location: Worth Ryder Art Gallery (AAP 116)
#
# May 9—Friday, May 13: Finals Week(Fri
# Date: May 9—Friday, May 13
# Name: Finals Week(Fri
# Time: unknown
# Location: unknown
#
# May 13: Spring Semester ends(Sat
# Date: May 13
# Name: Spring Semester ends(Sat
# Time: unknown
# Location: unknown
#
# May 14: Cal Commencement(Tues
# Date: May 14
# Name: Cal Commencement(Tues
# Time: unknown
# Location: unknown
#
# May 17: Art Practice Commencement(Wed
# Date: May 17
# Name: Art Practice Commencement(Wed
# Time: unknown
# Location: unknown
#
# May 18: Spring 2022 Senior Show closes in Worth Ryder Art Gallery(Fri
# Date: May 18
# Name: Spring 2022 Senior Show closes in Worth Ryder Art Gallery(Fri
# Time: unknown
# Location: unknown
#
# May 20: Departmental meeting
# Date: May 20
# Name: Departmental meeting
# Time: unknown
# Location: unknown
#
# Aug. 23: MFA campus orientation and lunch, 10am-12pm(Tue
# Date: Aug. 23
# Name: MFA campus orientation and lunch
# Time: 10am-12pm(Tue
# Location: unknown
#
# Aug. 24: Art Practice Undergraduate Self-Guided Studios Tour, 12-2:30pm(Wed
# Date: Aug. 24
# Name: Art Practice Undergraduate Self-Guided Studios Tour
# Time: 12-2:30pm(Wed
# Location: unknown
#
# Aug. 25: Instruction begins
# Date: Aug. 25
# Name: Instruction begins
# Time: unknown
# Location: unknown
#
# Sept. 1: Wednesday Workshop: Art Practice Major Application info session, 12-1pm(Mon
# Date: Sept. 1
# Name: Wednesday Workshop: Art Practice Major Application info session
# Time: 12-1pm(Mon
# Location: unknown
#
# Sept. 6: Holiday: Labor Day(Tue
# Date: Sept. 6
# Name: Holiday: Labor Day(Tue
# Time: unknown
# Location: unknown
#
# Sept. 14: Bruce Cohen Scholarship Award Launch, Worth Ryder Art Gallery, 4-6pm(Wed
# Date: Sept. 14
# Name: Bruce Cohen Scholarship Award Launch
# Time: Worth Ryder Art Gallery
# Location: 4-6pm
#
# Sept. 15: Last day to add/drop a class(Sun
# Date: Sept. 15
# Name: Last day to add/drop a class(Sun
# Time: unknown
# Location: unknown
#
# Sept. 19: Art Practice Major applications due(Fri
# Date: Sept. 19
# Name: Art Practice Major applications due(Fri
# Time: unknown
# Location: unknown
#
# Sept. 24: Faculty meeting(Mon
# Date: Sept. 24
# Name: Faculty meeting(Mon
# Time: unknown
# Location: unknown
#
# Sept. 27: Materials Quik-Grant applications open
# Date: Sept. 27
# Name: Materials Quik-Grant applications open
# Time: unknown
# Location: unknown
#
# Oct. 2: Art Practice hosts Cal Vet Tailgate/Clay Date, Ceramics Labs, Wurster Hall(Sun
# Date: Oct. 2
# Name: Art Practice hosts Cal Vet Tailgate/Clay Date
# Time: Ceramics Labs
# Location: Wurster Hall
#
# Oct. 10: Materials Quik-Grant applications due(Mon
# Date: Oct. 10
# Name: Materials Quik-Grant applications due(Mon
# Time: unknown
# Location: unknown
#
# Oct. 11: Indigenous People’s Day (not official holiday)(Fr
# Date: Oct. 11
# Name: Indigenous People’s Day (not official holiday)(Fr
# Time: unknown
# Location: unknown
#
# Oct. 22: Faculty meeting(Sat
# Date: Oct. 22
# Name: Faculty meeting(Sat
# Time: unknown
# Location: unknown
#
# Oct. 23: Art Practice hosts Cal Vet Tailgate/Clay Date, Ceramics Labs, Wurster Hall(Mon
# Date: Oct. 23
# Name: Art Practice hosts Cal Vet Tailgate/Clay Date
# Time: Ceramics Labs
# Location: Wurster Hall
#
# Oct. 25: Materials Quik-Grant awards announced(Wed
# Date: Oct. 25
# Name: Materials Quik-Grant awards announced(Wed
# Time: unknown
# Location: unknown
#
# Oct. 27: Lunchtime Workshop: “So You’re Thinking About Going to Grad School in the Arts…” 12-1pm, zoom(Sat
# Date: Oct. 27
# Name: Lunchtime Workshop: “So You’re Thinking About Going to Grad School in the Arts…” 12-1pm
# Time: zoom(Sat
# Location: unknown
#
# Oct. 30: Art Practice hosts Cal Vet Tailgate/Clay Date, Ceramics Labs, Wurster Hall
# Date: Oct. 30
# Name: Art Practice hosts Cal Vet Tailgate/Clay Date
# Time: Ceramics Labs
# Location: Wurster Hall
#
# Nov. 13: Art Practice hosts Cal Vet Tailgate/Clay Date, Ceramics Labs, Wurster Hall(Fri
# Date: Nov. 13
# Name: Art Practice hosts Cal Vet Tailgate/Clay Date
# Time: Ceramics Labs
# Location: Wurster Hall
#
# Nov. 19: Faculty meeting (closed session)(Wed
# Date: Nov. 19
# Name: Faculty meeting (closed session)(Wed
# Time: unknown
# Location: unknown
#
# Nov. 24: Non-Instructional Day(Th
# Date: Nov. 24
# Name: Non-Instructional Day(Th
# Time: unknown
# Location: unknown
#
# Nov. 25: Holiday: Thanksgiving(Fri
# Date: Nov. 25
# Name: Holiday: Thanksgiving(Fri
# Time: unknown
# Location: unknown
#
# Nov. 26: Holiday: Thanksgiving
# Date: Nov. 26
# Name: Holiday: Thanksgiving
# Time: unknown
# Location: unknown
#
# Dec. 2: Senior Thesis Exhibition “Coalescence” opens to the public: 4-6pm, Worth Ryder Art Gallery(Fri
# Date: Dec. 2
# Name: Senior Thesis Exhibition “Coalescence” opens to the public: 4-6pm
# Time: Worth Ryder Art Gallery(Fri
# Location: unknown
#
# Dec. 3: Spring 2022 Honors Studio Program applications due, 5pm(Mon
# Date: Dec. 3
# Name: Spring 2022 Honors Studio Program applications due
# Time: 5pm(Mon
# Location: unknown
#
# Dec. 6—Friday, Dec. 10: RRR Week(Mon
# Date: Dec. 6—Friday, Dec. 10
# Name: RRR Week(Mon
# Time: unknown
# Location: unknown
#
# Dec. 6: Senior Thesis Exhibition “Coalescence” artist talks: 12-1pm, Worth Ryder Art Gallery(Wed
# Date: Dec. 6
# Name: Senior Thesis Exhibition “Coalescence” artist talks: 12-1pm
# Time: Worth Ryder Art Gallery(Wed
# Location: unknown
#
# Dec. 8: Senior Thesis Exhibition “Coalescence” artist talks: 12-1pm, Worth Ryder Art Gallery(Thurs
# Date: Dec. 8
# Name: Senior Thesis Exhibition “Coalescence” artist talks: 12-1pm
# Time: Worth Ryder Art Gallery(Thurs
# Location: unknown
#
# Dec. 9: Artwork removal day: all student artwork cleared out from all studios(Fri
# Date: Dec. 9
# Name: Artwork removal day: all student artwork cleared out from all studios(Fri
# Time: unknown
# Location: unknown
#
# Dec. 10: Studio Clean-Up Day(Fri
# Date: Dec. 10
# Name: Studio Clean-Up Day(Fri
# Time: unknown
# Location: unknown
#
# Dec. 10: MFA 2nd Year Reviews(Mon
# Date: Dec. 10
# Name: MFA 2nd Year Reviews(Mon
# Time: unknown
# Location: unknown
#
# Dec. 13–Friday, Dec. 17: Finals Week(Fri
# Date: Dec. 13–Friday, Dec. 17
# Name: Finals Week(Fri
# Time: unknown
# Location: unknown
#
# Dec. 17: MFA 1st Year Reviews(Fri
# Date: Dec. 17
# Name: MFA 1st Year Reviews(Fri
# Time: unknown
# Location: unknown
#
# Dec. 17: Fall semester ends
# Date: Dec. 17
# Name: Fall semester ends
# Time: unknown
# Location: unknown
#
# May 23: Summer Session A begins
# Date: May 23
# Name: Summer Session A begins
# Time: unknown
# Location: unknown
#
# June 3: 2020 MFA Artists’ Talk, BAMPFA, 4:30pm (Zoom)(Fri
# Date: June 3
# Name: 2020 MFA Artists’ Talk
# Time: BAMPFA
# Location: 4:30pm (Zoom)
#
# June 11: MFA 2021 Exhibition opens at BAMPFA(Sun
# Date: June 11
# Name: MFA 2021 Exhibition opens at BAMPFA(Sun
# Time: unknown
# Location: unknown
#
# June 20: MFA 2020 Exhibition closes at BAMPFA(Wed
# Date: June 20
# Name: MFA 2020 Exhibition closes at BAMPFA(Wed
# Time: unknown
# Location: unknown
#
# June 23: 2021 MFA Artists’ Talk, BAMPFA, 4:30pm (Zoom)
# Date: June 23
# Name: 2021 MFA Artists’ Talk
# Time: BAMPFA
# Location: 4:30pm (Zoom)
#
# July 6: Summer Session D begins(Tue
# Date: July 6
# Name: Summer Session D begins(Tue
# Time: unknown
# Location: unknown
#
# July 6: Transfer Student Orientation (email Raty Syka syka@berkeley.edu for Zoom link)(Sun
# Date: July 6
# Name: Transfer Student Orientation (email Raty Syka syka@berkeley.edu for Zoom link)(Sun
# Time: unknown
# Location: unknown
#
# July 11: MFA 2021 Exhibition closes at BAMPFA
# Date: July 11
# Name: MFA 2021 Exhibition closes at BAMPFA
# Time: unknown
# Location: unknown
#
# January 14: Departmental Meeting(Fri
# Date: January 14
# Name: Departmental Meeting(Fri
# Time: unknown
# Location: unknown
#
# January 15: Golden Bears Orientation: Transfer Student Orientation (email syka@berkeley.edu for link)(Fri
# Date: January 15
# Name: Golden Bears Orientation: Transfer Student Orientation (email syka@berkeley.edu for link)(Fri
# Time: unknown
# Location: unknown
#
# January 15: Honors Critique Program: application deadline(Fri
# Date: January 15
# Name: Honors Critique Program: application deadline(Fri
# Time: unknown
# Location: unknown
#
# January 15: Worth Ryder Art Gallery Internship: application deadline(Mon
# Date: January 15
# Name: Worth Ryder Art Gallery Internship: application deadline(Mon
# Time: unknown
# Location: unknown
#
# January 18: Holiday: Martin Luther King, Jr. Day (Tue
# Date: January 18
# Name: Holiday: Martin Luther King
# Time: Jr. Day (Tue
# Location: unknown
#
# January 19: Instruction begins(Fri
# Date: January 19
# Name: Instruction begins(Fri
# Time: unknown
# Location: unknown
#
# January 29: MFA First Year exhibition opening: “When Things Get Back to Normal,” 6-7pm PST
# Date: January 29
# Name: MFA First Year exhibition opening: “When Things Get Back to Normal
# Time: ” 6-7pm PST
# Location: unknown
#
# February 1: Summer courses posted on Course Catalog(Mon
# Date: February 1
# Name: Summer courses posted on Course Catalog(Mon
# Time: unknown
# Location: unknown
#
# February 1: Materials Quik-Grant applications open(Wed
# Date: February 1
# Name: Materials Quik-Grant applications open(Wed
# Time: unknown
# Location: unknown
#
# February 3: Town Hall meeting, 12-1pm(Fri
# Date: February 3
# Name: Town Hall meeting
# Time: 12-1pm(Fri
# Location: unknown
#
# February 5: Departmental Meeting, 10:30am(Fri
# Date: February 5
# Name: Departmental Meeting
# Time: 10:30am(Fri
# Location: unknown
#
# February 12: Art Major Application Q+A Session (Zoom link
# Date: February 12
# Name: Art Major Application Q+A Session (Zoom link
# Time: unknown
# Location: unknown
#
# February 12: Virtual Studio Night #1, hosted by the AP Student Collaborative(Sun
# Date: February 12
# Name: Virtual Studio Night #1
# Time: hosted by the AP Student Collaborative(Sun
# Location: unknown
#
# February 14: Materials Quik-Grant deadline: Application link.(Mon
# Date: February 14
# Name: Materials Quik-Grant deadline: Application link.(Mon
# Time: unknown
# Location: unknown
#
# February 15: Holiday(Fri
# Date: February 15
# Name: Holiday(Fri
# Time: unknown
# Location: unknown
#
# February 19: Art Major Application deadline, midnight(Fri
# Date: February 19
# Name: Art Major Application deadline
# Time: midnight(Fri
# Location: unknown
#
# February 19: Materials Quik-Grant notifications(Fri
# Date: February 19
# Name: Materials Quik-Grant notifications(Fri
# Time: unknown
# Location: unknown
#
# February 19: MFA First Year exhibition performance/reading, 6-7pm PST (Mon
# Date: February 19
# Name: MFA First Year exhibition performance/reading
# Time: 6-7pm PST (Mon
# Location: unknown
#
# February 22: Ceramics Visiting Artist Lecture Series: Anina Major, 1-2pm PST(Fri
# Date: February 22
# Name: Ceramics Visiting Artist Lecture Series: Anina Major
# Time: 1-2pm PST(Fri
# Location: unknown
#
# February 26: Virtual Studio Night #2, hosted by the AP Student Collaborative
# Date: February 26
# Name: Virtual Studio Night #2
# Time: hosted by the AP Student Collaborative
# Location: unknown
#
# March 1: Ceramics Visiting Artist Lecture Series: Woody Othello, 9-10am PST(Mon
# Date: March 1
# Name: Ceramics Visiting Artist Lecture Series: Woody Othello
# Time: 9-10am PST(Mon
# Location: unknown
#
# March 22—March 26: Spring Recess(Fri
# Date: March 22—March 26
# Name: Spring Recess(Fri
# Time: unknown
# Location: unknown
#
# March 26: Holiday(Mon
# Date: March 26
# Name: Holiday(Mon
# Time: unknown
# Location: unknown
#
# March 29: Ceramics Visiting Artist Lecture Series: Ahn Lee, 1-2pm PST(Fri
# Date: March 29
# Name: Ceramics Visiting Artist Lecture Series: Ahn Lee
# Time: 1-2pm PST(Fri
# Location: unknown
#
# April 2: Departmental Meeting(Fri
# Date: April 2
# Name: Departmental Meeting(Fri
# Time: unknown
# Location: unknown
#
# April 2: Worth Ryder Gallery opening receptions: "Handing Off: Art in Pandemic Times: A Virtual Mail Art Exhibition” and “Unruly Objects in the Uncanny Valley,” 5-6pm PST (Zoom link)(Wed
# Date: April 2
# Name: Worth Ryder Gallery opening receptions: "Handing Off: Art in Pandemic Times: A Virtual Mail Art Exhibition” and “Unruly Objects in the Uncanny Valley
# Time: ” 5-6pm PST (Zoom link)(Wed
# Location: unknown
#
# April 7: Asma Kazmi & Santhi Kavuri-Bauer Lecture, 9am PST(Mon
# Date: April 7
# Name: Asma Kazmi & Santhi Kavuri-Bauer Lecture
# Time: 9am PST(Mon
# Location: unknown
#
# April 12: Ceramics Visiting Artist Lecture Series: Sharif Farrag, 11am-12pm PST(Wed
# Date: April 12
# Name: Ceramics Visiting Artist Lecture Series: Sharif Farrag
# Time: 11am-12pm PST(Wed
# Location: unknown
#
# April 14: Ceramics Visiting Artist Lecture Series: Gerardo Monterrubio, 1-2pm PST(Thur
# Date: April 14
# Name: Ceramics Visiting Artist Lecture Series: Gerardo Monterrubio
# Time: 1-2pm PST(Thur
# Location: unknown
#
# April 15: Discussion: Through the Eyes of Elders: Weaving Histories of the Philippines & U.S. through Story & Ritual, 6pm PST(Mon
# Date: April 15
# Name: Discussion: Through the Eyes of Elders: Weaving Histories of the Philippines & U.S. through Story & Ritual
# Time: 6pm PST(Mon
# Location: unknown
#
# May 3–Friday, May 7: RRR Week(Tues
# Date: May 3–Friday, May 7
# Name: RRR Week(Tues
# Time: unknown
# Location: unknown
#
# May 4: Departmental Meeting(Mon
# Date: May 4
# Name: Departmental Meeting(Mon
# Time: unknown
# Location: unknown
#
# May 10–Friday, May 14: Finals Week(Wed
# Date: May 10–Friday, May 14
# Name: Finals Week(Wed
# Time: unknown
# Location: unknown
#
# May 12: Opening reception: “HomeStudio” / ART 185 Senior Projects classes, 5-6pm (Zoom)(Thurs
# Date: May 12
# Name: Opening reception: “HomeStudio” / ART 185 Senior Projects classes
# Time: 5-6pm (Zoom)(Thurs
# Location: unknown
#
# May 13: Opening reception: “Game Design: Demo Day” / ART 172: Advanced Digital Media: Computer Graphics Studio, 6-9pm (Zoom)(Fr
# Date: May 13
# Name: Opening reception: “Game Design: Demo Day” / ART 172: Advanced Digital Media: Computer Graphics Studio
# Time: 6-9pm (Zoom)(Fr
# Location: unknown
#
# May 14: Fall 2021 Honors Studio Program applications due, 5pm(Fri
# Date: May 14
# Name: Fall 2021 Honors Studio Program applications due
# Time: 5pm(Fri
# Location: unknown
#
# May 14: Spring semester ends(Fri
# Date: May 14
# Name: Spring semester ends(Fri
# Time: unknown
# Location: unknown
#
# May 14: MFA 2020 Exhibition opens at BAMPFA, 6pm PST(Mon
# Date: May 14
# Name: MFA 2020 Exhibition opens at BAMPFA
# Time: 6pm PST(Mon
# Location: unknown
#
# May 17: Art Practice Commencement Ceremony, 3-5pm PST
# Date: May 17
# Name: Art Practice Commencement Ceremony
# Time: 3-5pm PST
# Location: unknown
#
# August 20: MFA Class of 2022 Orientation, 4-6pm(Mon
# Date: August 20
# Name: MFA Class of 2022 Orientation
# Time: 4-6pm(Mon
# Location: unknown
#
# August 24: Golden Bears Orientation: Transfer Student Orientation (recorded)(Tue
# Date: August 24
# Name: Golden Bears Orientation: Transfer Student Orientation (recorded)(Tue
# Time: unknown
# Location: unknown
#
# August 25: Golden Bears Orientation: Art Major Portfolio workshop (recorded)(Wed
# Date: August 25
# Name: Golden Bears Orientation: Art Major Portfolio workshop (recorded)(Wed
# Time: unknown
# Location: unknown
#
# August 26: First day of instruction(Thu
# Date: August 26
# Name: First day of instruction(Thu
# Time: unknown
# Location: unknown
#
# August 27: Worth Ryder Art Gallery Internship: application deadline(Fri
# Date: August 27
# Name: Worth Ryder Art Gallery Internship: application deadline(Fri
# Time: unknown
# Location: unknown
#
# August 28: Departmental Meeting
# Date: August 28
# Name: Departmental Meeting
# Time: unknown
# Location: unknown
#
# September 2: Art Practice Town Hall (semester kick-off), 12-1pm(Tue
# Date: September 2
# Name: Art Practice Town Hall (semester kick-off)
# Time: 12-1pm(Tue
# Location: unknown
#
# September 8: Art Practice Town Hall, 12-1pm(Wed
# Date: September 8
# Name: Art Practice Town Hall
# Time: 12-1pm(Wed
# Location: unknown
#
# September 9: Art Practice Town Hall, 12-1pm(Wed
# Date: September 9
# Name: Art Practice Town Hall
# Time: 12-1pm(Wed
# Location: unknown
#
# September 9: Honors Critique Program: application deadline(Fri
# Date: September 9
# Name: Honors Critique Program: application deadline(Fri
# Time: unknown
# Location: unknown
#
# September 11: Departmental Meeting(Wed
# Date: September 11
# Name: Departmental Meeting(Wed
# Time: unknown
# Location: unknown
#
# September 16: Add/Drop deadline (undergraduate classes)(Mon
# Date: September 16
# Name: Add/Drop deadline (undergraduate classes)(Mon
# Time: unknown
# Location: unknown
#
# September 21: Worth Ryder Art Gallery Internship Art Talk Series: Destinee Ross-Sutton, Curator, Say It Loud, 12-1pm(Mon
# Date: September 21
# Name: Worth Ryder Art Gallery Internship Art Talk Series: Destinee Ross-Sutton
# Time: Curator
# Location: Say It Loud
#
# September 21: Wiesenfeld Artist Lecture: William Pope L., 6:30-8pm(Fri
# Date: September 21
# Name: Wiesenfeld Artist Lecture: William Pope L.
# Time: 6:30-8pm(Fri
# Location: unknown
#
# September 25: Add/Drop deadline (graduate classes)(Mon
# Date: September 25
# Name: Add/Drop deadline (graduate classes)(Mon
# Time: unknown
# Location: unknown
#
# September 28: Worth Ryder Art Gallery Internship Art Talk Series(: Remote Viewing with Artists Tyler Coburn & Ian Hatcher, 12-1pm(Fri
# Date: September 28
# Name: Worth Ryder Art Gallery Internship Art Talk Series(: Remote Viewing with Artists Tyler Coburn & Ian Hatcher
# Time: 12-1pm(Fri
# Location: unknown
#
# October 2: Departmental Meeting(Mon
# Date: October 2
# Name: Departmental Meeting(Mon
# Time: unknown
# Location: unknown
#
# October 5: Declaring the Art Major: Early application deadline for priority Spring 2021 enrollment(Wed
# Date: October 5
# Name: Declaring the Art Major: Early application deadline for priority Spring 2021 enrollment(Wed
# Time: unknown
# Location: unknown
#
# October 7: Graphic Knowledge Series: Art for the Asking: The History of the Graphic Arts Loan Collection and A Conversation with GALC Award Winners, 4:10-5pm(Mon
# Date: October 7
# Name: Graphic Knowledge Series: Art for the Asking: The History of the Graphic Arts Loan Collection and A Conversation with GALC Award Winners
# Time: 4:10-5pm(Mon
# Location: unknown
#
# October 12: Wiesenfeld Artist Lecture: Sherin Gurguis, 6:30-8pm(Wed
# Date: October 12
# Name: Wiesenfeld Artist Lecture: Sherin Gurguis
# Time: 6:30-8pm(Wed
# Location: unknown
#
# October 14: Graphic Knowledge Series: How-to Make an Impression: A Tour and History of Presses at Two Printmaking Studios, 4:10-5pm(Fri
# Date: October 14
# Name: Graphic Knowledge Series: How-to Make an Impression: A Tour and History of Presses at Two Printmaking Studios
# Time: 4:10-5pm(Fri
# Location: unknown
#
# October 16: Declaring the Art Major: Deadline for Fall 2020(Mon
# Date: October 16
# Name: Declaring the Art Major: Deadline for Fall 2020(Mon
# Time: unknown
# Location: unknown
#
# October 19: Wiesenfeld Artist Lecture: Connie Zheng: How to Talk to Seeds, 6:30-8pm(Wed
# Date: October 19
# Name: Wiesenfeld Artist Lecture: Connie Zheng: How to Talk to Seeds
# Time: 6:30-8pm(Wed
# Location: unknown
#
# October 21: Graphic Knowledge Series: Lasting Impressions: An Art Historian’s Perspective on Printmaking and the Graphic Arts Loan Collection, 4:10-5pm(Wed
# Date: October 21
# Name: Graphic Knowledge Series: Lasting Impressions: An Art Historian’s Perspective on Printmaking and the Graphic Arts Loan Collection
# Time: 4:10-5pm(Wed
# Location: unknown
#
# October 28: Graphic Knowledge Series: Impressive Art: An Artists Panel on Printmaking, with Randy Hussong, Emily Gui (MFA ‘21
# Date: October 28
# Name: Graphic Knowledge Series: Impressive Art: An Artists Panel on Printmaking
# Time: with Randy Hussong
# Location: Emily Gui (MFA ‘21
#
# November 2: Worth Ryder Art Gallery Internship Art Talk Series: Vivian Sming of Sming Sming Books: Independent Art Publishing, 12-1pm(Mon
# Date: November 2
# Name: Worth Ryder Art Gallery Internship Art Talk Series: Vivian Sming of Sming Sming Books: Independent Art Publishing
# Time: 12-1pm(Mon
# Location: unknown
#
# November 2: Wiesenfeld Artist Lecture: Lava Thomas in Conversation with Kenyatta A.C. Hinkle, 6:30-8pm(Mon
# Date: November 2
# Name: Wiesenfeld Artist Lecture: Lava Thomas in Conversation with Kenyatta A.C. Hinkle
# Time: 6:30-8pm(Mon
# Location: unknown
#
# November 9: Worth Ryder Art Gallery Internship Art Talk Series: John Held Jr. Mail Art, 12-1pm(Wed
# Date: November 9
# Name: Worth Ryder Art Gallery Internship Art Talk Series: John Held Jr. Mail Art
# Time: 12-1pm(Wed
# Location: unknown
#
# November 11: Academic and administrative holiday(Fri
# Date: November 11
# Name: Academic and administrative holiday(Fri
# Time: unknown
# Location: unknown
#
# November 20: Departmental Meeting(Wed
# Date: November 20
# Name: Departmental Meeting(Wed
# Time: unknown
# Location: unknown
#
# November 25: Non-Instructional Day(Thu - Fri
# Date: November 25
# Name: Non-Instructional Day(Thu - Fri
# Time: unknown
# Location: unknown
#
# November 26-27: Thanksgiving Holiday
# Date: November 26-27
# Name: Thanksgiving Holiday
# Time: unknown
# Location: unknown
#
# December 4: Departmental Meeting(Mon
# Date: December 4
# Name: Departmental Meeting(Mon
# Time: unknown
# Location: unknown
#
# December 7–Friday, December 11: RRR Week(Fri
# Date: December 7–Friday, December 11
# Name: RRR Week(Fri
# Time: unknown
# Location: unknown
#
# December 11: Last day of instruction(Tue
# Date: December 11
# Name: Last day of instruction(Tue
# Time: unknown
# Location: unknown
#
# December 15: MFA Application deadline(Fri
# Date: December 15
# Name: MFA Application deadline(Fri
# Time: unknown
# Location: unknown
#
# December 18, 2020: Fall semester officially ends
# Date: December 18, 2020
# Name: Fall semester officially ends
# Time: unknown
# Location: unknown

# %%
p.contents
# Out:
# [<a href="https://dac.berkeley.edu/web-accessibility"><span style="text-decoration:underline">Accessibility</span></a>,
#  <span style="text-decoration:underline"><br/></span>,
#  <a href="https://ophd.berkeley.edu/policies-and-procedures/nondiscrimination-policy-statement"><span style="text-decoration:underline">Nondiscrimination</span></a>,
#  <span style="text-decoration:underline"><br/></span>,
#  <a href="https://security.berkeley.edu/policy/privacy-statement-uc-berkeley-websites"><span style="text-decoration:underline">Privacy</span></a>]

# %%
event_list
# Out:
# [{'Date': 'August 30',
#   'Name': 'Reception: “Black chicagoland is…”',
#   'Time': '5-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'May. 3',
#   'Name': 'Senior Exhibit “Textured Overflow.”',
#   'Time': '5-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'April. 12',
#   'Name': 'Blood Pressure and Here Lies',
#   'Time': '4-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Jan. 18',
#   'Name': 'Reception: Cacophonies of Resistance',
#   'Time': '4-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Feb. 8',
#   'Name': 'Closing Reception and Catalogue Preview: Cacophonies of Resistance',
#   'Time': '4-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Feb. 22',
#   'Name': 'Reception: Emergenc(y): Afghan Lives Beyond the Forever War',
#   'Time': '5-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Feb 23 - 28',
#   'Name': 'Remembering a Future#2',
#   'Time': 'Performance Lecture by Amanullah Mojadidi(Sat',
#   'Location': 'unknown'},
#  {'Date': 'Mar.4',
#   'Name': 'Writing Afghan Lives Beyond the Forever War A Book Reading and Dance Performance',
#   'Time': '1-3pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Apr 12',
#   'Name': 'Reception: Honors Exhibit',
#   'Time': '5-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'May 3',
#   'Name': 'Reception: Senior Exhibit',
#   'Time': '5-7 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Aug. 24',
#   'Name': 'Instruction begins (in person)(Tues',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Aug. 30',
#   'Name': 'New lecturer orientation',
#   'Time': '12-1pm (online)(Wed',
#   'Location': 'unknown'},
#  {'Date': 'Aug.31',
#   'Name': 'Reception: Art for the Asking',
#   'Time': '4-6pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)urs'},
#  {'Date': 'Sept. 8',
#   'Name': '“New Bulldozer Alarm!” exhibition opening',
#   'Time': 'Platform Artspace',
#   'Location': '4-6pm'},
#  {'Date': 'Sept. 16',
#   'Name': 'Departmental meeting (online)(Sun',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 18',
#   'Name': 'Art Practice major applications due(Sun',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 2',
#   'Name': 'Fall 2022 Materials Quik-Grants due(Wed ',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct.19',
#   'Name': ' Honors Exhibition Opening Reception',
#   'Time': '4-6 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Oct.19',
#   'Name': "Badri Valian's “Virgins in Heaven",
#   'Time': '” exhibition opening',
#   'Location': '4-6pm'},
#  {'Date': 'Nov.16',
#   'Name': 'Senior Exhibit Opening Reception',
#   'Time': '4-6 pm',
#   'Location': 'Worth Ryder Art Gallery (AAPB 116)'},
#  {'Date': 'Jan. 18',
#   'Name': 'Instruction begins (online)(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Jan. 21',
#   'Name': 'Departmental meeting(Tue',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Jan. 25',
#   'Name': 'Artist Talk: Jeffrey Gibson',
#   'Time': 'Wiesenfeld Visiting Artist Lecture Series / Arts Research Center',
#   'Location': '4-5:30pm'},
#  {'Date': 'Jan. 26',
#   'Name': 'First Year MFA exhibition “Optimal Conditions” opens in Worth Ryder Art Gallery(Fri)',
#   'Time': 'Jan. 28: “Optimal Conditions” performance by Gericault De La Rose: 7-8:30pm',
#   'Location': 'accessible by live stream'},
#  {'Date': 'Jan. 31',
#   'Name': 'Instruction begins in-person (projected date',
#   'Time': 'subject to university change)',
#   'Location': 'unknown'},
#  {'Date': 'Feb. 8',
#   'Name': 'Artist Talk: Hajra Waheed',
#   'Time': 'Crisis and Creativity: Artists Speak / Wiesenfeld Visiting Artist Lecture Series / South Asia Studies',
#   'Location': '9am'},
#  {'Date': 'Feb. 9',
#   'Name': 'Deadline to add/drop classes(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Feb. 9',
#   'Name': 'Art Practice major application info session with Raty Syka and Stephanie Syjuco',
#   'Time': '12-1pm',
#   'Location': 'Zoom'},
#  {'Date': 'Feb. 18',
#   'Name': 'Art Practice major applications due(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Feb. 18',
#   'Name': '“Optimal Conditions” performance by Irma Yuliana Barbosa',
#   'Time': '5-6pm',
#   'Location': 'AAP 120'},
#  {'Date': 'Feb. 18',
#   'Name': 'Departmental meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Feb. 21',
#   'Name': 'Holiday (Tues',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Feb. 22—Tuesday, March 1',
#   'Name': 'Student exhibition TBA opens in Worth Ryder Art Gallery(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Feb. 28',
#   'Name': 'Artist Talk: The New Red Order',
#   'Time': 'Berkeley Arts + Design',
#   'Location': '6:30-8pm'},
#  {'Date': 'Mar. 2',
#   'Name': 'Exhibitions PROOF: 28 years of printmaking at UC Berkeley  and (Im)print open in Worth Ryder Art Gallery',
#   'Time': '4-6 pm.(Sun',
#   'Location': 'unknown'},
#  {'Date': 'March 6',
#   'Name': 'Materials Quik-Grant applications due(Tue',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'March 15',
#   'Name': 'Artist Talk: Dario Robleto',
#   'Time': 'Wiesenfeld Visiting Artist Lecture Series / Arts Research Center',
#   'Location': '4-5:30pm'},
#  {'Date': 'March 18',
#   'Name': 'Departmental meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'March 21—Friday, March 25',
#   'Name': 'Spring Break(Sat',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'March 26',
#   'Name': 'MFA Open Studios',
#   'Time': 'Richmond Field Station',
#   'Location': '10am-2pm'},
#  {'Date': 'March 30',
#   'Name': 'Visiting Artist: Aman Mojadidi',
#   'Time': 'Wiesenfeld Visiting Artist Lecture Series / Center for Middle Eastern Studies',
#   'Location': 'time 12:00 PM'},
#  {'Date': 'April 1',
#   'Name': 'Artist Talk: Wendy Red Star',
#   'Time': 'Wiesenfeld Visiting Artist Lecture Series / Arts Research Center',
#   'Location': '4-5:30pm'},
#  {'Date': 'April 1',
#   'Name': 'Deadline to change grading options(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'April 6',
#   'Name': 'Exhibition Opening: Embodied Entropy',
#   'Time': '4-6 pm',
#   'Location': 'Worth Ryder Art Gallery (AAP 116'},
#  {'Date': 'April 12',
#   'Name': 'Talk: Arundhati Roy',
#   'Time': 'Center for Race and Gender',
#   'Location': '4-5:30pmurs'},
#  {'Date': 'April 14',
#   'Name': "Artist Talk: Seitu Jones: George's Blues: An Investigation of George Washington Carver’s Legacy as an Artist and Cook",
#   'Time': 'Art',
#   'Location': 'Technology and Culture Colloquium '},
#  {'Date': 'April 15',
#   'Name': 'Departmental meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'April 18',
#   'Name': 'Artist Talk: Iman Mersal',
#   'Time': 'Wiesenfeld Visiting Artist Lecture Series / Center for Middle Eastern Studies',
#   'Location': 'time 5:00 PM'},
#  {'Date': 'May 2—Friday, May 6',
#   'Name': 'RRR Week(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 4',
#   'Name': 'Exhibition Opening: Extro-Introspection: Spring 2022 Senior Thesis Exhibition',
#   'Time': '4-6 pm',
#   'Location': 'Worth Ryder Art Gallery (AAP 116)'},
#  {'Date': 'May 9—Friday, May 13',
#   'Name': 'Finals Week(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 13',
#   'Name': 'Spring Semester ends(Sat',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 14',
#   'Name': 'Cal Commencement(Tues',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 17',
#   'Name': 'Art Practice Commencement(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 18',
#   'Name': 'Spring 2022 Senior Show closes in Worth Ryder Art Gallery(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 20',
#   'Name': 'Departmental meeting',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Aug. 23',
#   'Name': 'MFA campus orientation and lunch',
#   'Time': '10am-12pm(Tue',
#   'Location': 'unknown'},
#  {'Date': 'Aug. 24',
#   'Name': 'Art Practice Undergraduate Self-Guided Studios Tour',
#   'Time': '12-2:30pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'Aug. 25',
#   'Name': 'Instruction begins',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 1',
#   'Name': 'Wednesday Workshop: Art Practice Major Application info session',
#   'Time': '12-1pm(Mon',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 6',
#   'Name': 'Holiday: Labor Day(Tue',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 14',
#   'Name': 'Bruce Cohen Scholarship Award Launch',
#   'Time': 'Worth Ryder Art Gallery',
#   'Location': '4-6pm'},
#  {'Date': 'Sept. 15',
#   'Name': 'Last day to add/drop a class(Sun',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 19',
#   'Name': 'Art Practice Major applications due(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 24',
#   'Name': 'Faculty meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Sept. 27',
#   'Name': 'Materials Quik-Grant applications open',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 2',
#   'Name': 'Art Practice hosts Cal Vet Tailgate/Clay Date',
#   'Time': 'Ceramics Labs',
#   'Location': 'Wurster Hall'},
#  {'Date': 'Oct. 10',
#   'Name': 'Materials Quik-Grant applications due(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 11',
#   'Name': 'Indigenous People’s Day (not official holiday)(Fr',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 22',
#   'Name': 'Faculty meeting(Sat',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 23',
#   'Name': 'Art Practice hosts Cal Vet Tailgate/Clay Date',
#   'Time': 'Ceramics Labs',
#   'Location': 'Wurster Hall'},
#  {'Date': 'Oct. 25',
#   'Name': 'Materials Quik-Grant awards announced(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 27',
#   'Name': 'Lunchtime Workshop: “So You’re Thinking About Going to Grad School in the Arts…” 12-1pm',
#   'Time': 'zoom(Sat',
#   'Location': 'unknown'},
#  {'Date': 'Oct. 30',
#   'Name': 'Art Practice hosts Cal Vet Tailgate/Clay Date',
#   'Time': 'Ceramics Labs',
#   'Location': 'Wurster Hall'},
#  {'Date': 'Nov. 13',
#   'Name': 'Art Practice hosts Cal Vet Tailgate/Clay Date',
#   'Time': 'Ceramics Labs',
#   'Location': 'Wurster Hall'},
#  {'Date': 'Nov. 19',
#   'Name': 'Faculty meeting (closed session)(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Nov. 24',
#   'Name': 'Non-Instructional Day(Th',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Nov. 25',
#   'Name': 'Holiday: Thanksgiving(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Nov. 26',
#   'Name': 'Holiday: Thanksgiving',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 2',
#   'Name': 'Senior Thesis Exhibition “Coalescence” opens to the public: 4-6pm',
#   'Time': 'Worth Ryder Art Gallery(Fri',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 3',
#   'Name': 'Spring 2022 Honors Studio Program applications due',
#   'Time': '5pm(Mon',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 6—Friday, Dec. 10',
#   'Name': 'RRR Week(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 6',
#   'Name': 'Senior Thesis Exhibition “Coalescence” artist talks: 12-1pm',
#   'Time': 'Worth Ryder Art Gallery(Wed',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 8',
#   'Name': 'Senior Thesis Exhibition “Coalescence” artist talks: 12-1pm',
#   'Time': 'Worth Ryder Art Gallery(Thurs',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 9',
#   'Name': 'Artwork removal day: all student artwork cleared out from all studios(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 10',
#   'Name': 'Studio Clean-Up Day(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 10',
#   'Name': 'MFA 2nd Year Reviews(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 13–Friday, Dec. 17',
#   'Name': 'Finals Week(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 17',
#   'Name': 'MFA 1st Year Reviews(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'Dec. 17',
#   'Name': 'Fall semester ends',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 23',
#   'Name': 'Summer Session A begins',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'June 3',
#   'Name': '2020 MFA Artists’ Talk',
#   'Time': 'BAMPFA',
#   'Location': '4:30pm (Zoom)'},
#  {'Date': 'June 11',
#   'Name': 'MFA 2021 Exhibition opens at BAMPFA(Sun',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'June 20',
#   'Name': 'MFA 2020 Exhibition closes at BAMPFA(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'June 23',
#   'Name': '2021 MFA Artists’ Talk',
#   'Time': 'BAMPFA',
#   'Location': '4:30pm (Zoom)'},
#  {'Date': 'July 6',
#   'Name': 'Summer Session D begins(Tue',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'July 6',
#   'Name': 'Transfer Student Orientation (email Raty Syka syka@berkeley.edu for Zoom link)(Sun',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'July 11',
#   'Name': 'MFA 2021 Exhibition closes at BAMPFA',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'January 14',
#   'Name': 'Departmental Meeting(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'January 15',
#   'Name': 'Golden Bears Orientation: Transfer Student Orientation (email syka@berkeley.edu for link)(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'January 15',
#   'Name': 'Honors Critique Program: application deadline(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'January 15',
#   'Name': 'Worth Ryder Art Gallery Internship: application deadline(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'January 18',
#   'Name': 'Holiday: Martin Luther King',
#   'Time': 'Jr. Day (Tue',
#   'Location': 'unknown'},
#  {'Date': 'January 19',
#   'Name': 'Instruction begins(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'January 29',
#   'Name': 'MFA First Year exhibition opening: “When Things Get Back to Normal',
#   'Time': '” 6-7pm PST',
#   'Location': 'unknown'},
#  {'Date': 'February 1',
#   'Name': 'Summer courses posted on Course Catalog(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'February 1',
#   'Name': 'Materials Quik-Grant applications open(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'February 3',
#   'Name': 'Town Hall meeting',
#   'Time': '12-1pm(Fri',
#   'Location': 'unknown'},
#  {'Date': 'February 5',
#   'Name': 'Departmental Meeting',
#   'Time': '10:30am(Fri',
#   'Location': 'unknown'},
#  {'Date': 'February 12',
#   'Name': 'Art Major Application Q+A Session (Zoom link',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'February 12',
#   'Name': 'Virtual Studio Night #1',
#   'Time': 'hosted by the AP Student Collaborative(Sun',
#   'Location': 'unknown'},
#  {'Date': 'February 14',
#   'Name': 'Materials Quik-Grant deadline: Application link.(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'February 15',
#   'Name': 'Holiday(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'February 19',
#   'Name': 'Art Major Application deadline',
#   'Time': 'midnight(Fri',
#   'Location': 'unknown'},
#  {'Date': 'February 19',
#   'Name': 'Materials Quik-Grant notifications(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'February 19',
#   'Name': 'MFA First Year exhibition performance/reading',
#   'Time': '6-7pm PST (Mon',
#   'Location': 'unknown'},
#  {'Date': 'February 22',
#   'Name': 'Ceramics Visiting Artist Lecture Series: Anina Major',
#   'Time': '1-2pm PST(Fri',
#   'Location': 'unknown'},
#  {'Date': 'February 26',
#   'Name': 'Virtual Studio Night #2',
#   'Time': 'hosted by the AP Student Collaborative',
#   'Location': 'unknown'},
#  {'Date': 'March 1',
#   'Name': 'Ceramics Visiting Artist Lecture Series: Woody Othello',
#   'Time': '9-10am PST(Mon',
#   'Location': 'unknown'},
#  {'Date': 'March 22—March 26',
#   'Name': 'Spring Recess(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'March 26',
#   'Name': 'Holiday(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'March 29',
#   'Name': 'Ceramics Visiting Artist Lecture Series: Ahn Lee',
#   'Time': '1-2pm PST(Fri',
#   'Location': 'unknown'},
#  {'Date': 'April 2',
#   'Name': 'Departmental Meeting(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'April 2',
#   'Name': 'Worth Ryder Gallery opening receptions: "Handing Off: Art in Pandemic Times: A Virtual Mail Art Exhibition” and “Unruly Objects in the Uncanny Valley',
#   'Time': '” 5-6pm PST (Zoom link)(Wed',
#   'Location': 'unknown'},
#  {'Date': 'April 7',
#   'Name': 'Asma Kazmi & Santhi Kavuri-Bauer Lecture',
#   'Time': '9am PST(Mon',
#   'Location': 'unknown'},
#  {'Date': 'April 12',
#   'Name': 'Ceramics Visiting Artist Lecture Series: Sharif Farrag',
#   'Time': '11am-12pm PST(Wed',
#   'Location': 'unknown'},
#  {'Date': 'April 14',
#   'Name': 'Ceramics Visiting Artist Lecture Series: Gerardo Monterrubio',
#   'Time': '1-2pm PST(Thur',
#   'Location': 'unknown'},
#  {'Date': 'April 15',
#   'Name': 'Discussion: Through the Eyes of Elders: Weaving Histories of the Philippines & U.S. through Story & Ritual',
#   'Time': '6pm PST(Mon',
#   'Location': 'unknown'},
#  {'Date': 'May 3–Friday, May 7',
#   'Name': 'RRR Week(Tues',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 4',
#   'Name': 'Departmental Meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 10–Friday, May 14',
#   'Name': 'Finals Week(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 12',
#   'Name': 'Opening reception: “HomeStudio”\xa0/ ART 185 Senior Projects classes',
#   'Time': '5-6pm (Zoom)(Thurs',
#   'Location': 'unknown'},
#  {'Date': 'May 13',
#   'Name': 'Opening reception: “Game Design: Demo Day”\xa0/ ART 172: Advanced Digital Media: Computer Graphics Studio',
#   'Time': '6-9pm (Zoom)(Fr',
#   'Location': 'unknown'},
#  {'Date': 'May 14',
#   'Name': 'Fall 2021 Honors Studio Program applications due',
#   'Time': '5pm(Fri',
#   'Location': 'unknown'},
#  {'Date': 'May 14',
#   'Name': 'Spring semester ends(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'May 14',
#   'Name': 'MFA 2020 Exhibition opens at BAMPFA',
#   'Time': '6pm PST(Mon',
#   'Location': 'unknown'},
#  {'Date': 'May 17',
#   'Name': 'Art Practice Commencement Ceremony',
#   'Time': '3-5pm PST',
#   'Location': 'unknown'},
#  {'Date': 'August 20',
#   'Name': 'MFA Class of 2022 Orientation',
#   'Time': '4-6pm(Mon',
#   'Location': 'unknown'},
#  {'Date': 'August 24',
#   'Name': 'Golden Bears Orientation: Transfer Student Orientation (recorded)(Tue',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'August 25',
#   'Name': 'Golden Bears Orientation: Art Major Portfolio workshop (recorded)(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'August 26',
#   'Name': 'First day of instruction(Thu',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'August 27',
#   'Name': 'Worth Ryder Art Gallery Internship: application deadline(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'August 28',
#   'Name': 'Departmental Meeting',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'September 2',
#   'Name': 'Art Practice Town Hall (semester kick-off)',
#   'Time': '12-1pm(Tue',
#   'Location': 'unknown'},
#  {'Date': 'September 8',
#   'Name': 'Art Practice Town Hall',
#   'Time': '12-1pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'September 9',
#   'Name': 'Art Practice Town Hall',
#   'Time': '12-1pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'September 9',
#   'Name': 'Honors Critique Program: application deadline(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'September 11',
#   'Name': 'Departmental Meeting(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'September 16',
#   'Name': 'Add/Drop deadline (undergraduate classes)(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'September 21',
#   'Name': 'Worth Ryder Art Gallery Internship Art Talk Series: Destinee Ross-Sutton',
#   'Time': 'Curator',
#   'Location': 'Say It Loud'},
#  {'Date': 'September 21',
#   'Name': 'Wiesenfeld Artist Lecture: William Pope L.',
#   'Time': '6:30-8pm(Fri',
#   'Location': 'unknown'},
#  {'Date': 'September 25',
#   'Name': 'Add/Drop deadline (graduate classes)(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'September 28',
#   'Name': 'Worth Ryder Art Gallery Internship Art Talk Series(: Remote Viewing with Artists Tyler Coburn & Ian Hatcher',
#   'Time': '12-1pm(Fri',
#   'Location': 'unknown'},
#  {'Date': 'October 2',
#   'Name': 'Departmental Meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'October 5',
#   'Name': 'Declaring the Art Major: Early application deadline for priority Spring 2021 enrollment(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'October 7',
#   'Name': 'Graphic Knowledge Series: Art for the Asking: The History of the Graphic Arts Loan Collection and A Conversation with GALC Award Winners',
#   'Time': '4:10-5pm(Mon',
#   'Location': 'unknown'},
#  {'Date': 'October 12',
#   'Name': 'Wiesenfeld Artist Lecture: Sherin Gurguis',
#   'Time': '6:30-8pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'October 14',
#   'Name': 'Graphic Knowledge Series: How-to Make an Impression: A Tour and History of Presses at Two Printmaking Studios',
#   'Time': '4:10-5pm(Fri',
#   'Location': 'unknown'},
#  {'Date': 'October 16',
#   'Name': 'Declaring the Art Major: Deadline for Fall 2020(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'October 19',
#   'Name': 'Wiesenfeld Artist Lecture: Connie Zheng: How to Talk to Seeds',
#   'Time': '6:30-8pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'October 21',
#   'Name': 'Graphic Knowledge Series: Lasting Impressions: An Art Historian’s Perspective on Printmaking and the Graphic Arts Loan Collection',
#   'Time': '4:10-5pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'October 28',
#   'Name': 'Graphic Knowledge Series: Impressive Art: An Artists Panel on Printmaking',
#   'Time': 'with Randy Hussong',
#   'Location': 'Emily Gui (MFA ‘21'},
#  {'Date': 'November 2',
#   'Name': 'Worth Ryder Art Gallery Internship Art Talk Series: Vivian Sming of Sming Sming Books: Independent Art Publishing',
#   'Time': '12-1pm(Mon',
#   'Location': 'unknown'},
#  {'Date': 'November 2',
#   'Name': 'Wiesenfeld Artist Lecture: Lava Thomas in Conversation with Kenyatta A.C. Hinkle',
#   'Time': '6:30-8pm(Mon',
#   'Location': 'unknown'},
#  {'Date': 'November 9',
#   'Name': 'Worth Ryder Art Gallery Internship Art Talk Series: John Held Jr. Mail Art',
#   'Time': '12-1pm(Wed',
#   'Location': 'unknown'},
#  {'Date': 'November 11',
#   'Name': 'Academic and administrative holiday(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'November 20',
#   'Name': 'Departmental Meeting(Wed',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'November 25',
#   'Name': 'Non-Instructional Day(Thu - Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'November 26-27',
#   'Name': 'Thanksgiving Holiday',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'December 4',
#   'Name': 'Departmental Meeting(Mon',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'December 7–Friday, December 11',
#   'Name': 'RRR Week(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'December 11',
#   'Name': 'Last day of instruction(Tue',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'December 15',
#   'Name': 'MFA Application deadline(Fri',
#   'Time': 'unknown',
#   'Location': 'unknown'},
#  {'Date': 'December 18, 2020',
#   'Name': 'Fall semester officially ends',
#   'Time': 'unknown',
#   'Location': 'unknown'}]

# %% [markdown]
# ## Museums

# %%
# List out bay area museums
bay_area_museums = [
    {
        "Name": "Cantor Arts Center",
        "Links": [
            {
                "Link": "https://museum.stanford.edu/exhibitions",
                "Description": "Exhibitions"
            },
            {
                "Link": "https://museum.stanford.edu/programs", # need to use selenium
                "Description": "Programs & Events"
            }
        ]
    },
    {
        "Name": "de Young",
        "Links": [
            {
                "Link": "https://www.famsf.org/calendar",
                "Description": "Calendar"
            }
        ]
    },
    "Legion of Honor",
    "SF MoMA",
    "Institute of Contemporary Art San Jose",
    "Asian Art Museum",
    "Oakland Museum of California (OMCA)",
    "Cartoon Art Museum",
]

# %% [markdown]
# #### Cantor Arts Center - Programs & Events

# %%
# URL of the website to scrape
url = 'https://museum.stanford.edu/programs'

# Send a GET request to fetch the webpage content
response = requests.get(url)
html_content = response.content

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# %%
# Find elements a class
item_elements = soup.find_all("ul")

for i, item in enumerate(item_elements):
    print(i, item.get_text())
# Out:
# 0
#
# Visit
#
#
# Exhibitions
#
#
# Programs
#
#
# Collections
#
#
# Students & Faculty
#
#
# About
#
#
# Support
#
#
# 1
#
# Student Programs
#
#
# Family Programs
#
#
# Member Programs
#
#
# Academic Programs

# %%
item_elements[0]
# Out:
# <ul class="nav navbar-nav">
# <li class="nav-item">
# <a class="nav-link" data-drupal-link-system-path="node/4" href="/visit">Visit</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-drupal-link-system-path="node/5" href="/exhibitions">Exhibitions</a>
# </li>
# <li class="nav-item active">
# <a class="nav-link is-active" data-drupal-link-system-path="node/9" href="/programs">Programs</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="http://cantorcollection.stanford.edu/">Collections</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-drupal-link-system-path="node/14" href="/students-faculty">Students &amp; Faculty</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-drupal-link-system-path="node/125" href="/about">About</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" data-drupal-link-system-path="node/18" href="/support">Support</a>
# </li>
# </ul>

# %% [markdown]
# ### de Young - Calendar

# %%
def get_de_young_events():
    """
    Uses BeautifulSoup to scrape event info from the de Young
    Museum's calendar.
    """
    # Collect event info
    events_list = []
    
    # URL of the website to scrape
    url = "https://www.famsf.org/calendar"

    # Iterate through the pages
    for i in range(1, 10):
        
        print("PAGE ", i, " +"*40)
        url = "https://www.famsf.org/calendar" + f"?page={i}"
    
        # Send a GET request to fetch the webpage content
        response = requests.get(url)
        html_content = response.content
        
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # Find elements a class
        group_elements = soup.find_all(class_="mt-24 xl:mt-32")

        # If no pages left, exit loop
        if len(group_elements) == 0: # this will be 0 when we've gone through all the pages
            break
        
        for e in group_elements:
            # Instantiate list to collect tags
            tags = []
            # Extract title
            title = e.find("a").find("h3").get_text().strip()
            # Extract link
            link = e.find("a").get("href")
            # Extract date info
            date = e.find(class_="mt-12 text-secondary f-subheading-1").get_text()
            # Extract venue
            try:
                venue = e.find(class_="text-inherit pt-2 ml-8").get_text()
            except AttributeError:
                venue = "unknown"
            # Add tags
            event_type = e.find(class_="text-inherit pt-2").get_text().lower() # this is Exhibition or Event
            if event_type == "exhibition":
                tags.append("exhibition")
            if "tour" in title.lower():
                tags.append("tour")
            if "family" in title.lower():
                tags.append("family")
            if "reading" in title.lower():
                tags.append("reading")
            if "concert" in title.lower():
                tags.append("audio")
            if "song bath" in title.lower():
                tags.append("audio")
            if "workshop" in title.lower():
                tags.append("workshop")
            if "free" in title.lower():
                tags.append("free")
            if "opening" in title.lower():
                tags.append("opening")
            # if "Through" in date:
            #     multi_day = True # if multi_day = True, then date is the end date, otherwise date is the date of the event
            #     multi_day_type = 'daily'
            # Collect data
            events_list.append(
                {
                    "Title": title,
                    "Links": link,
                    "Date": date,
                    "Venue": venue,
                    "Tags": tags
                }
            )

    print(f"Collected {len(events_list)} events.")
    return events_list
    # return pd.DataFrame.from_records(events_list)
    
data = get_de_young_events()
# Out:
# PAGE  1  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# PAGE  2  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# PAGE  3  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# PAGE  4  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# Collected 53 events.

# %%
# Save data as json
file_path = 'site/data.json'

with open(file_path, 'w') as json_file:
    json.dump(data, json_file)

# %% [markdown]
# ## Galleries

# %%
# List out bay area galleries
bay_area_galleries = [
    {
        "Name": "Berkeley Art Center",
        "Links": [
            {
                "Link": "https://www.berkeleyartcenter.org/calendar",
                "Description": "Calendar"
            },
        ]
    },
]

# %%
def get_berkeley_art_center_events():
    """
    Uses BeautifulSoup to scrape event info from Berkeley Art 
    Center's calendar.
    """

    # Collect event info
    events_list = []
    
    # URL of the website to scrape
    url = "https://www.berkeleyartcenter.org/calendar"
    
    # Send a GET request to fetch the webpage content
    response = requests.get(url)
    html_content = response.content
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # We'll use this later to identify dates
    days_of_week = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

    # Get elements
    elements = soup.find_all(class_="col sqs-col-6 span-6")

    # Iterate through elements
    for e in elements:
        # If looking at past events, stop the loop
        if "past events" in e.find_previous("h1").text.lower():
            break
        # Otherwise, we're looking at current events --> collect events
        else:
            h3s = e.find_all("h3")
            # If there are any h3 elements
            if len(h3s) > 0:
                # Collect date(s)
                dates = []
                # Identify title
                title = h3s[0].get_text().strip()
                # Collect tags
                tags = []
                # Collect links
                links = []
                # Iterate through h3 elements
                for h in h3s:
                    if any(x in h.get_text().lower() for x in days_of_week):
                        dates.append(h.get_text().strip())
                    # Tag events
                    if "opening" in h.get_text().lower():
                        tags.append("opening")
                    if "in conversation" in h.get_text().lower():
                        tags.append("talk")
                    if "performance" in h.get_text().lower():
                        tags.append("performance")
                    if "workshop" in h.get_text().lower():
                        tags.append("workshop")
                # Combined dates
                date = " | ".join(dates)
                # Identify location
                if "on zoom" in date.lower():
                    venue = "Virtual"
                try:
                    "berkeley art center" in h3s[2].get_text().lower()
                    venue = h3s[2].get_text()
                except IndexError:
                    venue = "Berkeley Art Center"
                else:
                    venue = "Berkeley Art Center"
                # Get link
                link_elements = e.find_all("a")
                if len(link_elements) > 0:
                    for l in link_elements:
                        link_url = l.get("href")
                        if "eventbrite" in link_url.lower():
                            links.append({
                                "Link": link_url,
                                "Text": "Eventbrite"
                            })
                        elif ("berkeleyartcenter" in link_url.lower() and link_url.lower() != "https://www.berkeleyartcenter.org/upcoming-exhibitions"):
                            links.append({
                                "Link": link_url,
                                "Text": "Event Page"
                            })
                        else:
                            links.append({
                                "Link": link_url,
                                "Text": "unknown"
                            })
                # Collect event data
                events_list.append(
                    {
                        "Title": title,
                        "Links": links,
                        "Date": date,
                        "Venue": venue,
                        "Tags": tags
                    }
                )
    print(f"Collected {len(events_list)} events.")
    return events_list

data = get_berkeley_art_center_events()
# Out:
# Collected 3 events.

# %%
data
# Out:
# [{'Title': 'Artists in conversation: Arleene Correa Valencia',
#   'Links': [{'Link': 'https://www.eventbrite.com/e/697676016747?aff=oddtdtcreator',
#     'Text': 'Eventbrite'}],
#   'Date': 'Tuesday, August 29 from 7–8PM on zoom.',
#   'Venue': 'Berkeley Art Center',
#   'Tags': ['talk']},
#  {'Title': 'OÑI OCAN: A RITUAL PERFORMANCE BY COURTNEY DESIREE MORRIS',
#   'Links': [{'Link': 'https://www.eventbrite.com/e/oni-ocan-a-ritual-performance-by-courtney-desiree-morris-tickets-697681232347?aff=oddtdtcreator',
#     'Text': 'Eventbrite'}],
#   'Date': 'Friday, september 8, 6–8PM',
#   'Venue': 'Berkeley Art Center',
#   'Tags': ['performance']},
#  {'Title': 'Community Dinner',
#   'Links': [{'Link': 'https://www.eventbrite.com/e/705586196307?aff=oddtdtcreator',
#     'Text': 'Eventbrite'}],
#   'Date': 'Tuesday, August 29 from 7–8PM on zoom.',
#   'Venue': 'Berkeley Art Center',
#   'Tags': []}]

# %% [markdown]
# ## Selenium exp

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService

# Create a new instance of Chrome driver
driver = webdriver.Chrome()

# Open the URL
url = "https://www.famsf.org/calendar"
driver.get(url)

# Wait for the page to load (you might need to adjust the time)
driver.implicitly_wait(10)

# Find event elements
event_elements = driver.find_elements(By.CLASS_NAME, 'group')

# # Iterate through event elements and print event titles
# for event_element in event_elements:
#     title_element = event_element.find_element(By.CLASS_NAME, 'views-field-title')
#     event_title = title_element.text
#     print(event_title)

# Close the browser
driver.quit()

# %%
event_elements[0].text
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connection.py:395, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     394     self.putheader(header, value)
# --> 395 self.endheaders()
#     397 # If we're given a body we start sending that in chunks.
#
# File /opt/miniconda3/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/miniconda3/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File /opt/miniconda3/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connection.py:243, in HTTPConnection.connect(self)
#     242 def connect(self) -> None:
# --> 243     self.sock = self._new_conn()
#     244     if self._tunnel_host:
#     245         # If we're tunneling it means we're connected to our proxy.
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connection.py:218, in HTTPConnection._new_conn(self)
#     217 except OSError as e:
# --> 218     raise NewConnectionError(
#     219         self, f"Failed to establish a new connection: {e}"
#     220     ) from e
#     222 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10d770370>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[281], line 1
# ----> 1 event_elements[0].text
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:343, in WebDriver.execute(self, driver_command, params)
#     340     elif "sessionId" not in params:
#     341         params["sessionId"] = self.session_id
# --> 343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
#     345     self.error_handler.check_response(response)
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:291, in RemoteConnection.execute(self, command, params)
#     289 data = utils.dump_json(params)
#     290 url = f"{self._url}{path}"
# --> 291 return self._request(command_info[0], url, body=data)
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:312, in RemoteConnection._request(self, method, url, body)
#     309     body = None
#     311 if self.keep_alive:
# --> 312     response = self._conn.request(method, url, body=body, headers=headers)
#     313     statuscode = response.status
#     314 else:
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/_request_methods.py:110, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     107     urlopen_kw["body"] = body
#     109 if method in self._encode_url_methods:
# --> 110     return self.request_encode_url(
#     111         method,
#     112         url,
#     113         fields=fields,  # type: ignore[arg-type]
#     114         headers=headers,
#     115         **urlopen_kw,
#     116     )
#     117 else:
#     118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     140 if fields:
#     141     url += "?" + urlencode(fields)
# --> 143 return self.urlopen(method, url, **extra_kw)
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841 elif isinstance(new_e, (OSError, HTTPException)):
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#     849 # Keep track of the error for the retry warning.
#
# File ~/Documents/art.info/art.info/lib/python3.9/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     513 if new_retry.is_exhausted():
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     519 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=53924): Max retries exceeded with url: /session/d426708e3a39b73193e484b33dea1cdd/element/CC5CF4F38ADB67F31F262A39E7C7B575_element_31/text (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10d770370>: Failed to establish a new connection: [Errno 61] Connection refused'))
